# %%
#-*- coding: utf-8 -*-
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#RXX.py
from spacemathpy import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ghfifj,Nc,mi,mj,mS = sp.symbols('g_{hfifj},N_c,m_i,m_j,m_S',positive=True)
WidthHff(ghfifj,Nc,mi,mj,mS)#.factor()
WidthHff(1,1,1,1,np.linspace(120,130,10))
# Out:
#                         _____________________                      3/2
#                        ╱                   2  ⎛                  2⎞
#              2        ╱      ⎛2⋅mᵢ   2⋅m_j⎞   ⎜    ⎛2⋅mᵢ   2⋅m_j⎞ ⎟
# N_c⋅g_{hfifj} ⋅m_S⋅  ╱   4 - ⎜──── - ─────⎟  ⋅⎜4 - ⎜──── + ─────⎟ ⎟
#                    ╲╱        ⎝m_S     m_S ⎠   ⎝    ⎝m_S     m_S ⎠ ⎠
# ──────────────────────────────────────────────────────────────────────
#                                 128⋅π
# array([4.77265899, 4.81688695, 4.86111457, 4.90534187, 4.94956886,
#        4.99379554, 5.03802192, 5.08224801, 5.12647382, 5.17069936])

# %%
#Se necesitan masas de este orden para que esta funcion
#este definida
ft(mS)
ft(np.linspace(350,600,10))
# Out:
#                                    2
#  ⎛   ⎛      ___________    ⎞      ⎞
#  ⎜   ⎜     ╱         2     ⎟      ⎟
#  ⎜   ⎜    ╱      4⋅mₜ      ⎟      ⎟
#  ⎜   ⎜   ╱   1 - ─────  + 1⎟      ⎟
#  ⎜   ⎜  ╱            2     ⎟      ⎟
#  ⎜   ⎜╲╱          m_S      ⎟      ⎟
# -⎜log⎜─────────────────────⎟ - ⅈ⋅π⎟
#  ⎜   ⎜          ___________⎟      ⎟
#  ⎜   ⎜         ╱         2 ⎟      ⎟
#  ⎜   ⎜        ╱      4⋅mₜ  ⎟      ⎟
#  ⎜   ⎜1 -    ╱   1 - ───── ⎟      ⎟
#  ⎜   ⎜      ╱            2 ⎟      ⎟
#  ⎝   ⎝    ╲╱          m_S  ⎠      ⎠
# ─────────────────────────────────────
#                   4
# array([2.44676805+0.45126495j, 2.28902922+1.32682324j,
#        2.1352856 +1.81048299j, 1.98530313+2.18131067j,
#        1.83886904+2.49065509j, 1.69578922+2.75962027j,
#        1.55588605+2.99938209j, 1.41899654+3.21672788j,
#        1.28497068+3.4161558j , 1.1536701 +3.60083397j])

# %%
fb(mS)
fb(np.linspace(125,130,10))
# Out:
#                                     2
#  ⎛   ⎛      ____________    ⎞      ⎞
#  ⎜   ⎜     ╱          2     ⎟      ⎟
#  ⎜   ⎜    ╱      4⋅m_b      ⎟      ⎟
#  ⎜   ⎜   ╱   1 - ──────  + 1⎟      ⎟
#  ⎜   ⎜  ╱            2      ⎟      ⎟
#  ⎜   ⎜╲╱          m_S       ⎟      ⎟
# -⎜log⎜──────────────────────⎟ - ⅈ⋅π⎟
#  ⎜   ⎜          ____________⎟      ⎟
#  ⎜   ⎜         ╱          2 ⎟      ⎟
#  ⎜   ⎜        ╱      4⋅m_b  ⎟      ⎟
#  ⎜   ⎜1 -    ╱   1 - ────── ⎟      ⎟
#  ⎜   ⎜      ╱            2  ⎟      ⎟
#  ⎝   ⎝    ╲╱          m_S   ⎠      ⎠
# ──────────────────────────────────────
#                   4
# array([-9.07140878+10.67162072j, -9.10162345+10.68558354j,
#        -9.13174337+10.69948444j, -9.16176922+10.71332397j,
#        -9.19170164+10.72710267j, -9.22154129+10.74082107j,
#        -9.25128882+10.7544797j , -9.28094486+10.76807908j,
#        -9.31051004+10.78161971j, -9.339985  +10.79510212j])

# %%
gt(mS)
gt(np.linspace(125,130,10))
# Out:
#     2⎛m_S ⎞
# asin ⎜────⎟
#      ⎝2⋅mₜ⎠
# array([0.13628031, 0.13755328, 0.13883302, 0.14011955, 0.1414129 ,
#        0.14271307, 0.1440201 , 0.14533398, 0.14665475, 0.14798242])

# %%
gb(mS)
gb(np.linspace(125,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_b⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:70: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
At(mS)
At(np.linspace(100,1000,10))
# Out:
# ⎧                                               2
# ⎪                 2⎛m_S ⎞                   4⋅mₜ
# ⎪             asin ⎜────⎟               for ───── ≥ 1
# ⎪                  ⎝2⋅mₜ⎠                       2
# ⎪                                            m_S
# ⎪
# ⎪                                   2
# ⎪ ⎛   ⎛      ___________    ⎞      ⎞
# ⎪ ⎜   ⎜     ╱         2     ⎟      ⎟
# ⎪ ⎜   ⎜    ╱      4⋅mₜ      ⎟      ⎟
# ⎪ ⎜   ⎜   ╱   1 - ─────  + 1⎟      ⎟
# ⎨ ⎜   ⎜  ╱            2     ⎟      ⎟
# ⎪ ⎜   ⎜╲╱          m_S      ⎟      ⎟
# ⎪-⎜log⎜─────────────────────⎟ - ⅈ⋅π⎟
# ⎪ ⎜   ⎜          ___________⎟      ⎟
# ⎪ ⎜   ⎜         ╱         2 ⎟      ⎟
# ⎪ ⎜   ⎜        ╱      4⋅mₜ  ⎟      ⎟
# ⎪ ⎜   ⎜1 -    ╱   1 - ───── ⎟      ⎟
# ⎪ ⎜   ⎜      ╱            2 ⎟      ⎟
# ⎪ ⎝   ⎝    ╲╱          m_S  ⎠      ⎠
# ⎪─────────────────────────────────────    otherwise
# ⎪                  4
# ⎩
# ...

# %%
Ab(mS)
Ab(np.linspace(100,1000,10))
# Out:
# ⎧                                                 2
# ⎪                 2⎛ m_S ⎞                   4⋅m_b
# ⎪             asin ⎜─────⎟               for ────── ≥ 1
# ⎪                  ⎝2⋅m_b⎠                       2
# ⎪                                             m_S
# ⎪
# ⎪                                    2
# ⎪ ⎛   ⎛      ____________    ⎞      ⎞
# ⎪ ⎜   ⎜     ╱          2     ⎟      ⎟
# ⎪ ⎜   ⎜    ╱      4⋅m_b      ⎟      ⎟
# ⎪ ⎜   ⎜   ╱   1 - ──────  + 1⎟      ⎟
# ⎨ ⎜   ⎜  ╱            2      ⎟      ⎟
# ⎪ ⎜   ⎜╲╱          m_S       ⎟      ⎟
# ⎪-⎜log⎜──────────────────────⎟ - ⅈ⋅π⎟
# ⎪ ⎜   ⎜          ____________⎟      ⎟
# ⎪ ⎜   ⎜         ╱          2 ⎟      ⎟
# ⎪ ⎜   ⎜        ╱      4⋅m_b  ⎟      ⎟
# ⎪ ⎜   ⎜1 -    ╱   1 - ────── ⎟      ⎟
# ⎪ ⎜   ⎜      ╱            2  ⎟      ⎟
# ⎪ ⎝   ⎝    ╲╱          m_S   ⎠      ⎠
# ⎪──────────────────────────────────────    otherwise
# ⎪                  4
# ⎩
# ...

# %%
#mtop = sp.symbols('m_t',positive=True)
Ft(mS)#.simplify().subs(mtop,0.1)
Ft(np.linspace(120,130,10))
# Out:
#        ⎛            ⎛⎧                                               2    ⎞
#        ⎜            ⎜⎪                 2⎛m_S ⎞                   4⋅mₜ     ⎟
#        ⎜            ⎜⎪             asin ⎜────⎟               for ───── ≥ 1⎟
#        ⎜            ⎜⎪                  ⎝2⋅mₜ⎠                       2    ⎟
#        ⎜            ⎜⎪                                            m_S     ⎟
#        ⎜            ⎜⎪                                                    ⎟
#        ⎜            ⎜⎪                                   2                ⎟
#        ⎜            ⎜⎪ ⎛   ⎛      ___________    ⎞      ⎞                 ⎟
#        ⎜            ⎜⎪ ⎜   ⎜     ╱         2     ⎟      ⎟                 ⎟
#        ⎜⎛        2⎞ ⎜⎪ ⎜   ⎜    ╱      4⋅mₜ      ⎟      ⎟                 ⎟
#      2 ⎜⎜    4⋅mₜ ⎟ ⎜⎪ ⎜   ⎜   ╱   1 - ─────  + 1⎟      ⎟                 ⎟
# -8⋅mₜ ⋅⎜⎜1 - ─────⎟⋅⎜⎨ ⎜   ⎜  ╱            2     ⎟      ⎟                 ⎟ +
# ...

# %%
Fb(mS).simplify()#.subs(mtop,0.1)
Fb(np.linspace(120,130,10))
# Out:
# ⎧                    2 ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪              -8⋅m_b ⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟
# ⎪                      ⎝                            ⎝2⋅m_b⎠⎠
# ⎪              ──────────────────────────────────────────────                f
# ⎪                                      4
# ⎪                                   m_S
# ⎪
# ⎪     ⎛                                                                  2⎞
# ⎪     ⎜                             ⎛   ⎛         _______________⎞      ⎞ ⎟
# ⎨     ⎜                             ⎜   ⎜        ╱    2        2 ⎟      ⎟ ⎟
# ⎪   2 ⎜       2     ⎛   2        2⎞ ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_b  ⎟      ⎟ ⎟
# ⎪m_b ⋅⎜- 8⋅m_S  + 2⋅⎝m_S  - 4⋅m_b ⎠⋅⎜log⎜────────────────────────⎟ - ⅈ⋅π⎟ ⎟
# ⎪     ⎜                             ⎜   ⎜         _______________⎟      ⎟ ⎟
# ⎪     ⎜                             ⎜   ⎜        ╱    2        2 ⎟      ⎟ ⎟
# ⎪     ⎝                             ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_b  ⎠      ⎠ ⎠
# ...

# %%
ghtt,ghbb = sp.symbols('g_{htt},g_{hbb}',real=True)
AHgg(ghtt,ghbb,mS).simplify()
AHgg(0.2,0.1,np.linspace(120,130,10))
# Out:
# ⎧                                   ⎛            ⎛   2   ⎛   2        2⎞     2
# ⎪                           -16⋅m_W⋅⎜g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin
# ⎪                                   ⎝            ⎝
# ⎪                           ──────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪                    ⎛
# ⎪                    ⎜
# ⎪                    ⎜
# ⎪                    ⎜              ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪             -4⋅m_W⋅⎜4⋅g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟ + g_
# ⎪                    ⎜              ⎝                            ⎝2⋅m_b⎠⎠
# ⎪                    ⎜
# ⎪                    ⎝
# ⎪             ────────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪                    ⎛            ⎛
# ⎪                    ⎜            ⎜                         ⎛   ⎛         ____
# ⎨                    ⎜            ⎜                         ⎜   ⎜        ╱
# ...

# %%
WidthHgg(ghtt,ghbb,mS).simplify()
plt.loglog(np.linspace(125,1000,100),WidthHgg(0.2,0.1,np.linspace(125,1000,100)))
# Out:
# ⎧
# ⎪                                     2 │            ⎛   2   ⎛   2        2⎞
# ⎪                              \alphaₛ ⋅│g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅a
# ⎪                                       │            ⎝
# ⎪                              ───────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪                       │
# ⎪                       │
# ⎪                       │
# ⎪                     2 │              ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪              \alphaₛ ⋅│4⋅g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟ +
# ⎪                       │              ⎝                            ⎝2⋅m_b⎠⎠
# ⎪                       │
# ⎪                       │
# ⎪              ───────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪
# ⎪                       │            ⎛
# ⎨                       │            ⎜                           ⎛   ⎛
# ⎪                       │            ⎜                           ⎜   ⎜
# ...

# %%
Aht(ghtt,mS).simplify()
Aht(0.1,np.linspace(120,130,10))
# Out:
# ⎧                                 ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞
# ⎪              -64⋅g_{htt}⋅m_W⋅mₜ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟
# ⎪                                 ⎝                           ⎝2⋅mₜ⎠⎠
# ⎪              ───────────────────────────────────────────────────────
# ⎪                                            4
# ⎪                                       3⋅m_S
# ⎪
# ⎪                   ⎛
# ⎪                   ⎜                        ⎛   ⎛         ______________⎞
# ⎨                   ⎜                        ⎜   ⎜        ╱    2       2 ⎟
# ⎪                   ⎜     2   ⎛   2       2⎞ ⎜   ⎜m_S + ╲╱  m_S  - 4⋅mₜ  ⎟
# ⎪-16⋅g_{htt}⋅m_W⋅mₜ⋅⎜4⋅m_S  - ⎝m_S  - 4⋅mₜ ⎠⋅⎜log⎜───────────────────────⎟ - ⅈ
# ⎪                   ⎜                        ⎜   ⎜         ______________⎟
# ⎪                   ⎜                        ⎜   ⎜        ╱    2       2 ⎟
# ⎪                   ⎝                        ⎝   ⎝m_S - ╲╱  m_S  - 4⋅mₜ  ⎠
# ...

# %%
Ahb(ghbb,mS).simplify()
Ahb(0.1,np.linspace(120,130,10))
# Out:
# ⎧                                 ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪             -16⋅g_{hbb}⋅m_W⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟
# ⎪                                 ⎝                            ⎝2⋅m_b⎠⎠
# ⎪             ──────────────────────────────────────────────────────────
# ⎪                                            4
# ⎪                                       3⋅m_S
# ⎪
# ⎪                   ⎛
# ⎪                   ⎜                         ⎛   ⎛         _______________⎞
# ⎨                   ⎜                         ⎜   ⎜        ╱    2        2 ⎟
# ⎪                   ⎜     2   ⎛   2        2⎞ ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_b  ⎟
# ⎪-4⋅g_{hbb}⋅m_W⋅m_b⋅⎜4⋅m_S  - ⎝m_S  - 4⋅m_b ⎠⋅⎜log⎜────────────────────────⎟ -
# ⎪                   ⎜                         ⎜   ⎜         _______________⎟
# ⎪                   ⎜                         ⎜   ⎜        ╱    2        2 ⎟
# ⎪                   ⎝                         ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_b  ⎠
# ...

# %%
Af(ghtt,ghbb,mS).simplify()
Af(0.1,0.1,np.linspace(120,130,10))
# Out:
# ⎧                                   ⎛            ⎛   2   ⎛   2        2⎞     2
# ⎪                           -16⋅m_W⋅⎜g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin
# ⎪                                   ⎝            ⎝
# ⎪                           ──────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪                      ⎛
# ⎪                      ⎜
# ⎪                      ⎜
# ⎪                      ⎜            ⎛   2   ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪              -16⋅m_W⋅⎜g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜─────⎟⎟ + g_
# ⎪                      ⎜            ⎝                            ⎝2⋅m_b⎠⎠
# ⎪                      ⎜
# ⎪                      ⎝
# ⎪              ───────────────────────────────────────────────────────────────
# ⎪
# ⎪
# ⎪
# ⎪                    ⎛            ⎛
# ⎪                    ⎜            ⎜                         ⎛   ⎛         ____
# ⎨                    ⎜            ⎜                         ⎜   ⎜        ╱
# ...

# %%
fW(mS)
#Esta función no esta definda en este rango 
fW(np.linspace(120,130,10))
# Out:
#                                     2
#  ⎛   ⎛      ____________    ⎞      ⎞
#  ⎜   ⎜     ╱          2     ⎟      ⎟
#  ⎜   ⎜    ╱      4⋅m_W      ⎟      ⎟
#  ⎜   ⎜   ╱   1 - ──────  + 1⎟      ⎟
#  ⎜   ⎜  ╱            2      ⎟      ⎟
#  ⎜   ⎜╲╱          m_S       ⎟      ⎟
# -⎜log⎜──────────────────────⎟ - ⅈ⋅π⎟
#  ⎜   ⎜          ____________⎟      ⎟
#  ⎜   ⎜         ╱          2 ⎟      ⎟
#  ⎜   ⎜        ╱      4⋅m_W  ⎟      ⎟
#  ⎜   ⎜1 -    ╱   1 - ────── ⎟      ⎟
#  ⎜   ⎜      ╱            2  ⎟      ⎟
#  ⎝   ⎝    ╲╱          m_S   ⎠      ⎠
# ──────────────────────────────────────
#                   4
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:166: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-x))/(1-np.sqrt(1-x)))-1j*np.pi)**2; #######MODIFICADO#########(-sp.I*np.pi)
# array([nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj])

# %%
gW(mS)
gW(np.linspace(120,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_W⎠
# array([0.71019667, 0.72791606, 0.74607247, 0.76468432, 0.78377145,
#        0.80335522, 0.82345874, 0.84410703, 0.86532726, 0.887149  ])

# %%
AW(mS)
AW(np.linspace(120,130,10))
# Out:
# ⎧                                                 2
# ⎪                 2⎛ m_S ⎞                   4⋅m_W
# ⎪             asin ⎜─────⎟               for ────── ≥ 1
# ⎪                  ⎝2⋅m_W⎠                       2
# ⎪                                             m_S
# ⎪
# ⎪                                    2
# ⎪ ⎛   ⎛      ____________    ⎞      ⎞
# ⎪ ⎜   ⎜     ╱          2     ⎟      ⎟
# ⎪ ⎜   ⎜    ╱      4⋅m_W      ⎟      ⎟
# ⎪ ⎜   ⎜   ╱   1 - ──────  + 1⎟      ⎟
# ⎨ ⎜   ⎜  ╱            2      ⎟      ⎟
# ⎪ ⎜   ⎜╲╱          m_S       ⎟      ⎟
# ⎪-⎜log⎜──────────────────────⎟ - ⅈ⋅π⎟
# ⎪ ⎜   ⎜          ____________⎟      ⎟
# ⎪ ⎜   ⎜         ╱          2 ⎟      ⎟
# ⎪ ⎜   ⎜        ╱      4⋅m_W  ⎟      ⎟
# ⎪ ⎜   ⎜1 -    ╱   1 - ────── ⎟      ⎟
# ⎪ ⎜   ⎜      ╱            2  ⎟      ⎟
# ⎪ ⎝   ⎝    ╲╱          m_S   ⎠      ⎠
# ⎪──────────────────────────────────────    otherwise
# ⎪                  4
# ⎩
# ...

# %%
FW(mS).simplify()
FW(np.linspace(120,130,10))
# Out:
# ⎧               ⎛   4        2    2         2 ⎛   2        2⎞     2⎛ m_S ⎞⎞
# ⎪             2⋅⎜m_S  + 6⋅m_S ⋅m_W  + 12⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅asin ⎜─────⎟⎟
# ⎪               ⎝                                                  ⎝2⋅m_W⎠⎠
# ⎪             ─────────────────────────────────────────────────────────────
# ⎪                                             4
# ⎪                                          m_S
# ⎪
# ⎪  ⎛
# ⎪  ⎜                                              ⎛   ⎛         ______________
# ⎨  ⎜                                              ⎜   ⎜        ╱    2        2
# ⎪  ⎜   4        2    2        2 ⎛     2        2⎞ ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_W
# ⎪2⋅⎜m_S  + 6⋅m_S ⋅m_W  + 3⋅m_W ⋅⎝- m_S  + 2⋅m_W ⎠⋅⎜log⎜───────────────────────
# ⎪  ⎜                                              ⎜   ⎜         ______________
# ⎪  ⎜                                              ⎜   ⎜        ╱    2        2
# ⎪  ⎝                                              ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_W
# ...

# %%
ghWW = sp.symbols('g_{hWW}',real=True)
AhW(ghWW,mS).simplify()
AhW(0.1,np.linspace(120,130,10))
# Out:
# ⎧                       ⎛   4        2    2         2 ⎛   2        2⎞     2⎛ m
# ⎪             2⋅g_{hWW}⋅⎜m_S  + 6⋅m_S ⋅m_W  + 12⋅m_W ⋅⎝m_S  - 2⋅m_W ⎠⋅asin ⎜──
# ⎪                       ⎝                                                  ⎝2⋅
# ⎪             ────────────────────────────────────────────────────────────────
# ⎪                                               4
# ⎪                                            m_S ⋅m_W
# ⎪
# ⎪          ⎛
# ⎪          ⎜                                              ⎛   ⎛         ______
# ⎨          ⎜                                              ⎜   ⎜        ╱    2
# ⎪          ⎜   4        2    2        2 ⎛     2        2⎞ ⎜   ⎜m_S + ╲╱  m_S
# ⎪2⋅g_{hWW}⋅⎜m_S  + 6⋅m_S ⋅m_W  + 3⋅m_W ⋅⎝- m_S  + 2⋅m_W ⎠⋅⎜log⎜───────────────
# ⎪          ⎜                                              ⎜   ⎜         ______
# ⎪          ⎜                                              ⎜   ⎜        ╱    2
# ...

# %%
mCH = sp.symbols(r'm_{H^{\pm}}',positive=True)
fH(mCH,mS).simplify()
fH(200.0,np.linspace(120,130,10))
# Out:
#                                                2
#  ⎛   ⎛         ________________________⎞      ⎞
#  ⎜   ⎜        ╱    2                 2 ⎟      ⎟
#  ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟      ⎟
# -⎜log⎜─────────────────────────────────⎟ - ⅈ⋅π⎟
#  ⎜   ⎜         ________________________⎟      ⎟
#  ⎜   ⎜        ╱    2                 2 ⎟      ⎟
#  ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠      ⎠
# ─────────────────────────────────────────────────
#                         4
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:213: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-x))/(1-np.sqrt(1-x)))-1j*np.pi)**2;#######MODIFICADO#########(-sp.I*sp.pi)
# array([nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj, nan+nanj,
#        nan+nanj, nan+nanj, nan+nanj, nan+nanj])

# %%
gH(mCH,mS)
gH(200.0,np.linspace(120,130,10))
# Out:
#     2⎛     m_S      ⎞
# asin ⎜──────────────⎟
#      ⎝2⋅m_{H__{\pm}}⎠
# array([0.09283761, 0.09462139, 0.09642381, 0.09824495, 0.10008488,
#        0.10194366, 0.10382137, 0.10571807, 0.10763385, 0.10956876])

# %%
AH(mCH,mS).simplify()
AH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                                                                     2
# ⎪                  2⎛     m_S      ⎞                    4⋅m_{H__{\pm}}
# ⎪              asin ⎜──────────────⎟                for ─────────────── ≥ 1
# ⎪                   ⎝2⋅m_{H__{\pm}}⎠                             2
# ⎪                                                             m_S
# ⎪
# ⎪                                               2
# ⎪ ⎛   ⎛         ________________________⎞      ⎞
# ⎨ ⎜   ⎜        ╱    2                 2 ⎟      ⎟
# ⎪ ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟      ⎟
# ⎪-⎜log⎜─────────────────────────────────⎟ - ⅈ⋅π⎟
# ⎪ ⎜   ⎜         ________________________⎟      ⎟
# ⎪ ⎜   ⎜        ╱    2                 2 ⎟      ⎟
# ⎪ ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠      ⎠
# ⎪─────────────────────────────────────────────────         otherwise
# ⎪                        4
# ⎩
# ...

# %%
FH(mCH,mS).simplify()
FH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                          2 ⎛   2                 2     2⎛     m_S      ⎞⎞
# ⎪            4⋅m_{H__{\pm}} ⋅⎜m_S  - 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                            ⎝                            ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪            ──────────────────────────────────────────────────────────────
# ⎪                                            4
# ⎪                                         m_S
# ⎪
# ⎪                ⎛
# ⎪                ⎜                     ⎛   ⎛         ________________________⎞
# ⎨                ⎜                     ⎜   ⎜        ╱    2                 2 ⎟
# ⎪              2 ⎜   2               2 ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟
# ⎪4⋅m_{H__{\pm}} ⋅⎜m_S  + m_{H__{\pm}} ⋅⎜log⎜─────────────────────────────────⎟
# ⎪                ⎜                     ⎜   ⎜         ________________________⎟
# ⎪                ⎜                     ⎜   ⎜        ╱    2                 2 ⎟
# ...

# %%
gCH = sp.symbols(r'g_{H^{\pm}}',real=True)
AHc(gCH,mCH,mS).simplify()
AHc(0.3,200.0,np.linspace(120,130,10))
# Out:
# ⎧                               ⎛   2                 2     2⎛     m_S      ⎞⎞
# ⎪            4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  - 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                               ⎝                            ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪            ─────────────────────────────────────────────────────────────────
# ⎪                                              4
# ⎪                                           m_S
# ⎪
# ⎪                   ⎛
# ⎪                   ⎜                     ⎛   ⎛         ______________________
# ⎨                   ⎜                     ⎜   ⎜        ╱    2
# ⎪                   ⎜   2               2 ⎜   ⎜m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}
# ⎪4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  + m_{H__{\pm}} ⋅⎜log⎜───────────────────────────────
# ⎪                   ⎜                     ⎜   ⎜         ______________________
# ⎪                   ⎜                     ⎜   ⎜        ╱    2
# ⎪                   ⎝                     ⎝   ⎝m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}
# ...

# %%
Ahgaga(ghtt,ghbb,ghWW,gCH,mCH,mS)#.simplify()
Ahgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#                    ⎛                    ⎛⎧
#                    ⎜                    ⎜⎪                 2⎛     m_S      ⎞
#                    ⎜                    ⎜⎪             asin ⎜──────────────⎟
#                    ⎜                    ⎜⎪                  ⎝2⋅m_{H__{\pm}}⎠
#                    ⎜                    ⎜⎪
#                    ⎜                    ⎜⎪
#                    ⎜                    ⎜⎪
#                    ⎜                    ⎜⎪ ⎛   ⎛      _____________________
#                    ⎜                    ⎜⎪ ⎜   ⎜     ╱                   2
#                    ⎜                    ⎜⎪ ⎜   ⎜    ╱      4⋅m_{H__{\pm}}
#                    ⎜                  2 ⎜⎪ ⎜   ⎜   ╱   1 - ───────────────  +
#                    ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨ ⎜   ⎜  ╱                 2
#                    ⎜                    ⎜⎪ ⎜   ⎜╲╱               m_S
#                    ⎜                    ⎜⎪-⎜log⎜──────────────────────────────
# ...

# %%
WidthHgaga(ghtt,ghbb,ghWW,gCH,mCH,mS)#.simplify()
WidthHgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#
#                  │                   ⎛                    ⎛⎧
#                  │                   ⎜                    ⎜⎪                 2
#                  │                   ⎜                    ⎜⎪             asin
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪
#                  │                   ⎜                    ⎜⎪ ⎛   ⎛      ______
#                  │                   ⎜                    ⎜⎪ ⎜   ⎜     ╱
#                  │                   ⎜                    ⎜⎪ ⎜   ⎜    ╱      4
#                  │                   ⎜                  2 ⎜⎪ ⎜   ⎜   ╱   1 - ─
#                  │                   ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨ ⎜   ⎜  ╱
#                  │                   ⎜                    ⎜⎪ ⎜   ⎜╲╱
# ...

# %%
RTW(mS)#.simplify()
RTW(np.linspace(120,130,10))
# Out:
#
#
#
#        ⎛       2⎞ ⎛          2         4⎞
#      2 ⎜    m_W ⎟ ⎜    13⋅m_W    47⋅m_W ⎟
#   m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#        ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4⎞    ⎛   2⎞
#        ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_W    6⋅m_W ⎟    ⎜m_W ⎟
# - ─────────────────────────────────────── - ⎜─ - ────── + ──────⎟⋅log⎜────⎟ +
#                         2                   ⎜2       2        4 ⎟    ⎜   2⎟
#                    2⋅m_W                    ⎝     m_S      m_S  ⎠    ⎝m_S ⎠
#
#
#
#
#
#                             ⎛     ⎛          2⎞⎞
#                             ⎜   3 ⎜     3⋅m_W ⎟⎟
#                             ⎜m_S ⋅⎜-1 + ──────⎟⎟
# ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟
# ⎜    24⋅m_W    60⋅m_W ⎟     ⎜     ⎝      m_S  ⎠⎟
# ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟
# ⎜         2         4 ⎟     ⎜           3      ⎟
# ⎝      m_S       m_S  ⎠     ⎝      2⋅m_W       ⎠
# ────────────────────────────────────────────────
# ...

# %%
RTZ(mS)#.simplify()
RTZ(np.linspace(120,130,10))
# Out:
#
#
#
#        ⎛       2⎞ ⎛          2         4⎞
#      2 ⎜    m_Z ⎟ ⎜    13⋅m_Z    47⋅m_Z ⎟
#   m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#        ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4⎞    ⎛   2⎞
#        ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_Z    6⋅m_Z ⎟    ⎜m_Z ⎟
# - ─────────────────────────────────────── - ⎜─ - ────── + ──────⎟⋅log⎜────⎟ +
#                         2                   ⎜2       2        4 ⎟    ⎜   2⎟
#                    2⋅m_Z                    ⎝     m_S      m_S  ⎠    ⎝m_S ⎠
#
#
#
#
#
#                             ⎛     ⎛          2⎞⎞
#                             ⎜   3 ⎜     3⋅m_Z ⎟⎟
#                             ⎜m_S ⋅⎜-1 + ──────⎟⎟
# ⎛          2         4⎞     ⎜     ⎜         2 ⎟⎟
# ⎜    24⋅m_Z    60⋅m_Z ⎟     ⎜     ⎝      m_S  ⎠⎟
# ⎜3 - ─────── + ───────⎟⋅acos⎜──────────────────⎟
# ⎜         2         4 ⎟     ⎜           3      ⎟
# ⎝      m_S       m_S  ⎠     ⎝      2⋅m_Z       ⎠
# ────────────────────────────────────────────────
# ...

# %%
δZ
# Out:
# 304.6635823627211

# %%
WidthHWW(ghWW,mS)#.simplify()
WidthHWW(0.3,np.linspace(120,130,10))
# Out:
#              ⎛
#              ⎜
#              ⎜
#              ⎜       ⎛       2⎞ ⎛          2         4⎞
#              ⎜     2 ⎜    m_W ⎟ ⎜    13⋅m_W    47⋅m_W ⎟
#              ⎜  m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#              ⎜       ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2        4
#        2     ⎜       ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_W    6⋅m_W
# g_{hWW} ⋅m_S⋅⎜- ─────────────────────────────────────── - ⎜─ - ────── + ──────
#              ⎜                        2                   ⎜2       2        4
#              ⎜                   2⋅m_W                    ⎝     m_S      m_S
#              ⎜
#              ⎜
#              ⎜
#              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                       3    4
#                                                                  512⋅π ⋅m_W
#
#                                           ⎛     ⎛          2⎞⎞⎞
# ...

# %%
ghZZ = sp.symbols('g_{HZZ}',real=True)
WidthHZZ(ghZZ,mS)#.simplify()
WidthHZZ(0.3,np.linspace(120,130,10))
# Out:
#                       ⎛
#                       ⎜
#                       ⎜
#                       ⎜       ⎛       2⎞ ⎛          2         4⎞
#                       ⎜     2 ⎜    m_Z ⎟ ⎜    13⋅m_Z    47⋅m_Z ⎟
#                       ⎜  m_S ⋅⎜1 - ────⎟⋅⎜2 - ─────── + ───────⎟
#                       ⎜       ⎜       2⎟ ⎜         2         4 ⎟   ⎛         2
#                 2     ⎜       ⎝    m_S ⎠ ⎝      m_S       m_S  ⎠   ⎜3   9⋅m_Z
# \delta_Z⋅g_{HZZ} ⋅m_S⋅⎜- ─────────────────────────────────────── - ⎜─ - ──────
#                       ⎜                        2                   ⎜2       2
#                       ⎜                   2⋅m_Z                    ⎝     m_S
#                       ⎜
#                       ⎜
#                       ⎜
#                       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            3
# ...

# %%
BRhfifj(ghtt,3,mb['symbol'],mb['symbol'])
BRhfifj(0.1,3.0,mb['value'],mb['value'])
# Out:
#                                             3/2
#                              ⎛        2    ⎞
#                         2    ⎜  16⋅m_b     ⎟
# 9.97340425531915⋅g_{htt} ⋅mₕ⋅⎜- ─────── + 4⎟
#                              ⎜      2      ⎟
#                              ⎝    mₕ       ⎠
# ───────────────────────────────────────────────
#                        π
# 31.579591172991595

# %%
BRhgaga(ghtt,ghbb,ghWW,gCH,mCH)
BRhgaga(0.1,0.2,0.3,0.11,np.linspace(200,300,10))
# Out:
#
#                                   │                   ⎛                    ⎛⎧
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                    ⎜⎪
#                                   │                   ⎜                  2 ⎜⎪
#                                   │                   ⎜    4⋅m_{H__{\pm}} ⋅⎜⎨
# ...

# %%
BRhWW(ghWW)
BRhWW(0.3)
# Out:
#                               ⎛
#                               ⎜
#                               ⎜
#                               ⎜                                    ⎛      4
#                               ⎜                                    ⎜60⋅m_W
#                               ⎜                                    ⎜─────── -
#                               ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜    4
#                          2    ⎜  ⎜6⋅m_W    9⋅m_W    3⎟    ⎜m_W ⎟   ⎝  mₕ
# 0.415558510638298⋅g_{hWW} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ───────────
#                               ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                               ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                               ⎜
#                               ⎜
#                               ⎜
#                               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             3
# ...

# %%
BRhZZ(ghZZ)
BRhZZ(0.2)
# Out:
#                                        ⎛
#                                        ⎜
#                                        ⎜
#                                        ⎜                                    ⎛
#                                        ⎜                                    ⎜6
#                                        ⎜                                    ⎜─
#                                        ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜
#                                   2    ⎜  ⎜6⋅m_Z    9⋅m_Z    3⎟    ⎜m_Z ⎟   ⎝
# 0.103889627659574⋅\delta_Z⋅g_{HZZ} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ──
#                                        ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                                        ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                                        ⎜
#                                        ⎜
#                                        ⎜
#                                        ⎝
# ...

# %%
BRhgg(ghtt,ghbb)
BRhgg(0.1,0.2)
# Out:
#
#                               │              ⎛               ⎛⎧
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪
#                               │              ⎜               ⎜⎪ ⎛   ⎛ ⎛      _
#                               │              ⎜               ⎜⎪ ⎜   ⎜ ⎜     ╱
#                               │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜   ⎜ ⎜    ╱
#                               │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜   ⎜-⎜   ╱
#                               │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜   ⎜ ⎜  ╱
#                               │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜   ⎜ ⎝╲╱
# ...

# %%
Rbotbot(ghtt,ghbb)
Rbotbot(0.1,0.2)
# Out:
#
#                   │              ⎛               ⎛⎧
#                   │              ⎜               ⎜⎪                    2⎛  mₕ
#                   │              ⎜               ⎜⎪                asin ⎜─────
#                   │              ⎜               ⎜⎪                     ⎝2⋅m_b
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪
#                   │              ⎜               ⎜⎪ ⎛   ⎛ ⎛      _____________
#                   │              ⎜               ⎜⎪ ⎜   ⎜ ⎜     ╱        2
#                   │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜   ⎜ ⎜    ╱    4⋅m_b
#                   │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜   ⎜-⎜   ╱   - ────── + 1
#                   │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜   ⎜ ⎜  ╱         2
#                   │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜   ⎜ ⎝╲╱        mₕ
# ...

# %%
ghtautau = sp.symbols(r'g_{h\tau\tau}',real=True)
Rtautau(ghtt,ghbb,ghtautau).subs(
    {mb['symbol']:mb['value'],
    mta['symbol']:mta['value'],
    mt['symbol']:mt['value'],
    mh['symbol']:mh['value'],
    mW['symbol']:mW['value'],
    g['symbol']:g['value']}).n()
Rtautau(0.1,0.0,0.1)
# Out:
#                               2 ⎛                            2          2
# 677984807.200825⋅g_{h\tau\tau} ⋅⎝0.000891217768417104⋅g_{hbb}  + g_{hbb} ⋅(-4.
#
#                                                     2
# 11713480447646e-5 - 4.84023174411982e-5⋅ⅈ) + g_{hbb} ⋅(-4.11713480447646e-5 +
#
#
# 4.84023174411982e-5⋅ⅈ) + 3.39125724304654e-5⋅g_{hbb}⋅g_{htt} + g_{hbb}⋅g_{htt}
#
#
# ⋅(-0.000153296795689362 - 0.000180220481476766⋅ⅈ) + g_{hbb}⋅g_{htt}⋅(-0.000153
#
#                                                                     2⎞
# 296795689362 + 0.000180220481476766⋅ⅈ) + 6.31347883183387e-5⋅g_{htt} ⎠
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2)))))-1j*np.pi)**2;#MODIFICADO#(-sp.I*np.pi)
# ...

# %%
Rtautau(ghtt,0,ghtautau).subs(
    {mb['symbol']:mb['value'],
    mta['symbol']:mta['value'],
    mt['symbol']:mt['value'],
    mh['symbol']:mh['value'],
    mW['symbol']:mW['value'],
    g['symbol']:g['value']}).n()
Rtautau(0,ghbb,ghtautau).subs(
    {mb['symbol']:mb['value'],
    mta['symbol']:mta['value'],
    mt['symbol']:mt['value'],
    mh['symbol']:mh['value'],
    mW['symbol']:mW['value'],
    g['symbol']:g['value']}).n()
# Out:
#                               2        2
# 42804.4272856738⋅g_{h\tau\tau} ⋅g_{htt}
#                               2        2
# 548405.009961564⋅g_{h\tau\tau} ⋅g_{hbb}

# %%
tt = np.linspace(0,1,100)
bb = tt
tautau = bb
plt.plot(tt,Rtautau(tt,0,tautau),label='Rtau(ghtt,0,ghtautau), ghbb=0');
plt.plot(bb,Rtautau(0,bb,tautau),label='Rtau(0,ghbb,ghtautau), ghtt=0');
plt.plot(tautau,Rtautau(0,bb,tautau),label='Rtau(0,ghbb,ghtautau), ghtt=0');
plt.plot(tautau,Rtautau(tt,0,tautau),label='Rtau(ghtt,0,ghtautau), ghtt=0');
plt.legend();
# Out:
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4.0)*(np.log((1+np.sqrt(1-((4*mtop**2)/(mS**2))))/(1-np.sqrt(1-((4*mtop**2)/(mS**2)))))-1j*np.pi)**2;#MODIFICADO#(-sp.I*np.pi)
# /home/moises/miniconda3/lib/python3.7/site-packages/spacemathpy/RXX.py:70: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;

# %%
RWW(ghtt,ghbb,ghWW)
RWW(0.1,0.2,0.01)
# Out:
#
#              │              ⎛               ⎛⎧
#              │              ⎜               ⎜⎪                    2⎛  mₕ ⎞
#              │              ⎜               ⎜⎪                asin ⎜─────⎟
#              │              ⎜               ⎜⎪                     ⎝2⋅m_b⎠
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪ ⎛   ⎛ ⎛      ______________
#              │              ⎜               ⎜⎪ ⎜   ⎜ ⎜     ╱        2
#              │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜   ⎜ ⎜    ╱    4⋅m_b
#              │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜   ⎜-⎜   ╱   - ────── + 1  + 1
#              │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜   ⎜ ⎜  ╱         2
#              │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜   ⎜ ⎝╲╱        mₕ
#              │              ⎜  ⎝ mₕ       ⎠ ⎜⎪-⎜log⎜──────────────────────────
# ...

# %%
RZZ(ghtt,ghbb,ghZZ)
RZZ(0.1,0.2,0.01)
# Out:
#
#              │              ⎛               ⎛⎧
#              │              ⎜               ⎜⎪                    2⎛  mₕ ⎞
#              │              ⎜               ⎜⎪                asin ⎜─────⎟
#              │              ⎜               ⎜⎪                     ⎝2⋅m_b⎠
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪
#              │              ⎜               ⎜⎪ ⎛   ⎛ ⎛      ______________
#              │              ⎜               ⎜⎪ ⎜   ⎜ ⎜     ╱        2
#              │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜   ⎜ ⎜    ╱    4⋅m_b
#              │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜   ⎜-⎜   ╱   - ────── + 1  + 1
#              │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜   ⎜ ⎜  ╱         2
#              │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜   ⎜ ⎝╲╱        mₕ
#              │              ⎜  ⎝ mₕ       ⎠ ⎜⎪-⎜log⎜──────────────────────────
# ...

# %%
Rgaga(ghtt,ghbb,ghWW,gCH,mCH)#.simplify()
Rgaga(0.1,0.2,0.3,0.001,200)
# Out:
#
#
#
#
#     │              ⎛               ⎛⎧
#     │              ⎜               ⎜⎪                    2⎛  mₕ ⎞
#     │              ⎜               ⎜⎪                asin ⎜─────⎟
#     │              ⎜               ⎜⎪                     ⎝2⋅m_b⎠
#     │              ⎜               ⎜⎪
#     │              ⎜               ⎜⎪
#     │              ⎜               ⎜⎪
#     │              ⎜               ⎜⎪ ⎛   ⎛ ⎛      ______________    ⎞ ⎞
#     │              ⎜               ⎜⎪ ⎜   ⎜ ⎜     ╱        2         ⎟ ⎟
#     │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜   ⎜ ⎜    ╱    4⋅m_b          ⎟ ⎟
#     │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜   ⎜-⎜   ╱   - ────── + 1  + 1⎟ ⎟
#     │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜   ⎜ ⎜  ╱         2           ⎟ ⎟
#     │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜   ⎜ ⎝╲╱        mₕ            ⎠ ⎟
#     │              ⎜  ⎝ mₕ       ⎠ ⎜⎪-⎜log⎜────────────────────────────⎟ - ⅈ⋅π
#     │              ⎜               ⎜⎪ ⎜   ⎜        ______________      ⎟
# ...

# %%
Rgg(ghtt,ghbb)
Rgg(0.1,0.2)
# Out:
#
#     │              ⎛               ⎛⎧
#     │              ⎜               ⎜⎪                  2⎛  mₕ ⎞
#     │              ⎜               ⎜⎪              asin ⎜─────⎟
#     │              ⎜               ⎜⎪                   ⎝2⋅m_b⎠
#     │              ⎜               ⎜⎪
#     │              ⎜               ⎜⎪
#     │              ⎜               ⎜⎪                                      2
#     │              ⎜               ⎜⎪ ⎛         ⎛      ______________    ⎞⎞
#     │              ⎜               ⎜⎪ ⎜         ⎜     ╱        2         ⎟⎟
#     │              ⎜  ⎛     2    ⎞ ⎜⎪ ⎜         ⎜    ╱    4⋅m_b          ⎟⎟
#     │              ⎜  ⎜4⋅m_b     ⎟ ⎜⎪ ⎜      log⎜   ╱   - ────── + 1  + 1⎟⎟
#     │8⋅g_{hbb}⋅m_b⋅⎜- ⎜────── - 1⎟⋅⎜⎨ ⎜         ⎜  ╱         2           ⎟⎟
#     │              ⎜  ⎜   2      ⎟ ⎜⎪ ⎜         ⎝╲╱        mₕ            ⎠⎟
#     │              ⎜  ⎝ mₕ       ⎠ ⎜⎪-⎜ⅈ⋅π - ─────────────────────────────⎟
# ...
