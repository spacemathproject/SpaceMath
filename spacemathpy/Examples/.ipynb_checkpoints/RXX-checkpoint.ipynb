# %%
#-*- coding: utf-8 -*-
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
from RXX import *
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
ghfifj,Nc,mi,mj,mS = sp.symbols('g_{hfifj},N_c,m_i,m_j,m_S',positive=True)
WidthHff(ghfifj,Nc,mi,mj,mS)#.factor()
WidthHff(1,1,1,1,np.linspace(120,130,10))
# Out:
#                         _____________________                      3/2
#                        ╱                   2  ⎛                  2⎞
#              2        ╱      ⎛2⋅mᵢ   2⋅m_j⎞   ⎜    ⎛2⋅mᵢ   2⋅m_j⎞ ⎟
# N_c⋅g_{hfifj} ⋅m_S⋅  ╱   4 - ⎜──── - ─────⎟  ⋅⎜4 - ⎜──── + ─────⎟ ⎟
#                    ╲╱        ⎝m_S     m_S ⎠   ⎝    ⎝m_S     m_S ⎠ ⎠
# ──────────────────────────────────────────────────────────────────────
#                                 128⋅π
# array([4.77265899, 4.81688695, 4.86111457, 4.90534187, 4.94956886,
#        4.99379554, 5.03802192, 5.08224801, 5.12647382, 5.17069936])

# %%
#Se necesitan masas de este orden para que esta funcion
#este definida
ft(mS)
ft(np.linspace(350,600,10))
# Out:
#        ⎛      ___________    ⎞
#        ⎜     ╱         2     ⎟
#        ⎜    ╱      4⋅mₜ      ⎟
#        ⎜   ╱   1 - ─────  + 1⎟
#        ⎜  ╱            2     ⎟
#  2    2⎜╲╱          m_S      ⎟
# π ⋅log ⎜─────────────────────⎟
#        ⎜          ___________⎟
#        ⎜         ╱         2 ⎟
#        ⎜        ╱      4⋅mₜ  ⎟
#        ⎜1 -    ╱   1 - ───── ⎟
#        ⎜      ╱            2 ⎟
#        ⎝    ╲╱          m_S  ⎠
# ──────────────────────────────
#               4
# array([0.203640054062027, 1.76045989850290, 3.27784864168799,
#        4.75811623518024, 6.20336278686887, 7.61550402444512,
#        8.99629293855966, 10.3473382818203, 11.6701204629730,
#        12.9660052697434], dtype=object)

# %%
fb(mS)
fb(np.linspace(125,130,10))
# Out:
#        ⎛      ____________    ⎞
#        ⎜     ╱          2     ⎟
#        ⎜    ╱      4⋅m_b      ⎟
#        ⎜   ╱   1 - ──────  + 1⎟
#        ⎜  ╱            2      ⎟
#  2    2⎜╲╱          m_S       ⎟
# π ⋅log ⎜──────────────────────⎟
#        ⎜          ____________⎟
#        ⎜         ╱          2 ⎟
#        ⎜        ╱      4⋅m_b  ⎟
#        ⎜1 -    ╱   1 - ────── ⎟
#        ⎜      ╱            2  ⎟
#        ⎝    ╲╱          m_S   ⎠
# ───────────────────────────────
#                4
# array([113.883488794321, 114.181695626866, 114.478967349411,
#        114.775310538421, 115.070731698062, 115.365237261282,
#        115.658833590881, 115.951526980542, 116.243323655856,
#        116.534229775324], dtype=object)

# %%
gt(mS)
gt(np.linspace(125,130,10))
# Out:
#     2⎛m_S ⎞
# asin ⎜────⎟
#      ⎝2⋅mₜ⎠
# array([0.13628031, 0.13755328, 0.13883302, 0.14011955, 0.1414129 ,
#        0.14271307, 0.1440201 , 0.14533398, 0.14665475, 0.14798242])

# %%
gb(mS)
gb(np.linspace(125,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_b⎠
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan])

# %%
At(mS)
At(np.linspace(100,1000,10))
# Out:
# ⎧                                        2
# ⎪             2⎛m_S ⎞                 m_S
# ⎪         asin ⎜────⎟            for ───── ≤ 1
# ⎪              ⎝2⋅mₜ⎠                    2
# ⎪                                    4⋅mₜ
# ⎪
# ⎪       ⎛      ___________    ⎞
# ⎪       ⎜     ╱         2     ⎟
# ⎪       ⎜    ╱      4⋅mₜ      ⎟
# ⎪       ⎜   ╱   1 - ─────  + 1⎟
# ⎨       ⎜  ╱            2     ⎟
# ⎪ 2    2⎜╲╱          m_S      ⎟
# ⎪π ⋅log ⎜─────────────────────⎟
# ⎪       ⎜          ___________⎟
# ⎪       ⎜         ╱         2 ⎟
# ⎪       ⎜        ╱      4⋅mₜ  ⎟
# ⎪       ⎜1 -    ╱   1 - ───── ⎟
# ⎪       ⎜      ╱            2 ⎟
# ⎪       ⎝    ╲╱          m_S  ⎠
# ⎪──────────────────────────────    otherwise
# ⎩              4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:59: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mtop**2)))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([0.0857518737730841, 0.37879055204528894, 1.0965196925794771,
#        2.97741130589564, 8.17148872978303, 12.9660052697434,
#        17.4271033076757, 21.6049672898514, 25.5386942919153,
#        29.2594131984998], dtype=object)

# %%
Ab(mS)
Ab(np.linspace(100,1000,10))
# Out:
# ⎧                                         2
# ⎪             2⎛ m_S ⎞                 m_S
# ⎪         asin ⎜─────⎟            for ────── ≤ 1
# ⎪              ⎝2⋅m_b⎠                     2
# ⎪                                     4⋅m_b
# ⎪
# ⎪       ⎛      ____________    ⎞
# ⎪       ⎜     ╱          2     ⎟
# ⎪       ⎜    ╱      4⋅m_b      ⎟
# ⎪       ⎜   ╱   1 - ──────  + 1⎟
# ⎨       ⎜  ╱            2      ⎟
# ⎪ 2    2⎜╲╱          m_S       ⎟
# ⎪π ⋅log ⎜──────────────────────⎟
# ⎪       ⎜          ____________⎟
# ⎪       ⎜         ╱          2 ⎟
# ⎪       ⎜        ╱      4⋅m_b  ⎟
# ⎪       ⎜1 -    ╱   1 - ────── ⎟
# ⎪       ⎜      ╱            2  ⎟
# ⎪       ⎝    ╲╱          m_S   ⎠
# ⎪───────────────────────────────    otherwise
# ⎩               4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:68: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mbot**2)))**2;
# array([99.3731845684116, 147.630432393693, 180.227825524811,
#        205.318595317375, 225.903673187814, 243.451718523481,
#        258.799886702404, 272.473984720617, 284.827402384175,
#        296.109862095330], dtype=object)

# %%
#mtop = sp.symbols('m_t',positive=True)
Ft(mS)#.simplify().subs(mtop,0.1)
Ft(np.linspace(120,130,10))
# Out:
#        ⎛                      ⎛⎧                                        2    ⎞
#        ⎜                      ⎜⎪             2⎛m_S ⎞                 m_S     ⎟
#        ⎜                      ⎜⎪         asin ⎜────⎟            for ───── ≤ 1⎟
#        ⎜                      ⎜⎪              ⎝2⋅mₜ⎠                    2    ⎟
#        ⎜                      ⎜⎪                                    4⋅mₜ     ⎟
#        ⎜                      ⎜⎪                                             ⎟
#        ⎜                      ⎜⎪       ⎛      ___________    ⎞               ⎟
#        ⎜                      ⎜⎪       ⎜     ╱         2     ⎟               ⎟
#        ⎜    2     ⎛    2    ⎞ ⎜⎪       ⎜    ╱      4⋅mₜ      ⎟               ⎟
#      4 ⎜ m_S      ⎜ m_S     ⎟ ⎜⎪       ⎜   ╱   1 - ─────  + 1⎟               ⎟
# 16⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜  ╱            2     ⎟               ⎟
#        ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜╲╱          m_S      ⎟               ⎟
#        ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜─────────────────────⎟               ⎟
#        ⎜                      ⎜⎪       ⎜          ___________⎟               ⎟
#        ⎜                      ⎜⎪       ⎜         ╱         2 ⎟               ⎟
#        ⎜                      ⎜⎪       ⎜        ╱      4⋅mₜ  ⎟               ⎟
#        ⎜                      ⎜⎪       ⎜1 -    ╱   1 - ───── ⎟               ⎟
#        ⎜                      ⎜⎪       ⎜      ╱            2 ⎟               ⎟
#        ⎜                      ⎜⎪       ⎝    ╲╱          m_S  ⎠               ⎟
#        ⎜                      ⎜⎪──────────────────────────────    otherwise  ⎟
#        ⎝                      ⎝⎩              4                              ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                          4
#                                       m_S
#
# ⎞
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎠
# ─
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([1.372615860115158, 1.3733862232113694, 1.3741652554586254,
#        1.3749530063140405, 1.3757495260120616, 1.3765548655762028,
#        1.3773690768309954, 1.37819221241426, 1.3790243257896706,
#        1.379865471259551], dtype=object)

# %%
Fb(mS).simplify()#.subs(mtop,0.1)
Fb(np.linspace(120,130,10))
# Out:
# ⎧                2 ⎛   2   ⎛   2        2⎞     2⎛m_S ⎞⎞
# ⎪           8⋅m_b ⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜────⎟⎟                     2
# ⎪                  ⎝                            ⎝2⋅mₜ⎠⎠                  m_S
# ⎪           ───────────────────────────────────────────             for ─────
# ⎪                                  4                                        2
# ⎪                               m_S                                     4⋅mₜ
# ⎪
# ⎪       ⎛                              ⎛          ______________⎞⎞
# ⎪       ⎜                              ⎜         ╱    2       2 ⎟⎟
# ⎨       ⎜        2 ⎛   2        2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟⎟
# ⎪       ⎜       π ⋅⎝m_S  - 4⋅m_b ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪       ⎜                              ⎜          ______________⎟⎟
# ⎪       ⎜                              ⎜         ╱    2       2 ⎟⎟
# ⎪     2 ⎜   2                          ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠⎟
# ⎪8⋅m_b ⋅⎜m_S  + ─────────────────────────────────────────────────⎟
# ⎪       ⎝                               4                        ⎠
# ⎪─────────────────────────────────────────────────────────────────    otherwis
# ⎪                                  4
# ⎩                               m_S
#
#
#
#
# ≤ 1
#
#
#
#
#
#
#
#
#
#
#
#
# e
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([0.010915575292705275, 0.010739380653097524, 0.01056800824810263,
#        0.010401285600745625, 0.010239047904780668, 0.010081137619315773,
#        0.009927404088221275, 0.009777703182605686, 0.009631896964774986,
#        0.00948985337221285], dtype=object)

# %%
ghtt,ghbb = sp.symbols('g_{htt},g_{hbb}',real=True)
AHgg(ghtt,ghbb,mS).simplify()
AHgg(0.2,0.1,np.linspace(120,130,10))
# Out:
# ⎧                             ⎛            ⎛   2   ⎛   2        2⎞     2⎛m_S ⎞
# ⎪                      16⋅m_W⋅⎜g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅asin ⎜────⎟
# ⎪                             ⎝            ⎝                            ⎝2⋅mₜ⎠
# ⎪                      ───────────────────────────────────────────────────────
# ⎪                                                                            4
# ⎪                                                                         m_S
# ⎪
# ⎪       ⎛            ⎛                              ⎛          ______________⎞
# ⎪       ⎜            ⎜                              ⎜         ╱    2       2 ⎟
# ⎨       ⎜            ⎜        2 ⎛   2        2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟
# ⎪       ⎜            ⎜       π ⋅⎝m_S  - 4⋅m_b ⎠⋅log ⎜────────────────────────⎟
# ⎪       ⎜            ⎜                              ⎜          ______________⎟
# ⎪       ⎜            ⎜                              ⎜         ╱    2       2 ⎟
# ⎪       ⎜            ⎜   2                          ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠
# ⎪16⋅m_W⋅⎜g_{hbb}⋅m_b⋅⎜m_S  + ─────────────────────────────────────────────────
# ⎪       ⎝            ⎝                               4
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                                                            4
# ⎩                                                                         m_S
#
# ⎞              ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞⎞
# ⎟ + g_{htt}⋅mₜ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟⎟
# ⎠              ⎝                           ⎝2⋅mₜ⎠⎠⎠
# ───────────────────────────────────────────────────                        for
#
#
#
# ⎞              ⎛                             ⎛          ______________⎞⎞⎞
# ⎟              ⎜                             ⎜         ╱    2       2 ⎟⎟⎟
# ⎟              ⎜        2 ⎛   2       2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟⎟⎟
# ⎟              ⎜       π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜────────────────────────⎟⎟⎟
# ⎟              ⎜                             ⎜          ______________⎟⎟⎟
# ⎟              ⎜                             ⎜         ╱    2       2 ⎟⎟⎟
# ⎟              ⎜   2                         ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠⎟⎟
# ⎟ + g_{htt}⋅mₜ⋅⎜m_S  + ────────────────────────────────────────────────⎟⎟
# ⎠              ⎝                              4                        ⎠⎠
# ─────────────────────────────────────────────────────────────────────────    o
#
#
#
#
#      2
#   m_S
#  ───── ≤ 1
#      2
#  4⋅mₜ
#
#
#
#
#
#
#
#
#
#
# therwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([0.29676785632967967, 0.29623322837677896, 0.29571875537027476,
#        0.29522378316385955, 0.29474768725625944, 0.2942898712343852,
#        0.29384976531183976, 0.29342682495619854, 0.29302052959896835,
#        0.2926303814225867], dtype=object)

# %%
WidthHgg(ghtt,ghbb,mS).simplify()
plt.loglog(np.linspace(125,1000,100),WidthHgg(0.2,0.1,np.linspace(125,1000,100)))
# Out:
# ⎧
# ⎪                                    2 │            ⎛   2   ⎛   2        2⎞
# ⎪                     0.28125⋅\alphaₛ ⋅│g_{hbb}⋅m_b⋅⎜m_S  + ⎝m_S  - 4⋅m_b ⎠⋅as
# ⎪                                      │            ⎝
# ⎪                     ────────────────────────────────────────────────────────
# ⎪
# ⎪                                                                            π
# ⎪
# ⎪
# ⎪                 │            ⎛                              ⎛         ______
# ⎨                 │            ⎜                              ⎜        ╱    2
# ⎪                 │            ⎜        2 ⎛   2        2⎞    2⎜m_S + ╲╱  m_S
# ⎪                 │            ⎜       π ⋅⎝m_S  - 4⋅m_b ⎠⋅log ⎜───────────────
# ⎪                 │            ⎜                              ⎜         ______
# ⎪                 │            ⎜                              ⎜        ╱    2
# ⎪               2 │            ⎜   2                          ⎝m_S - ╲╱  m_S
# ⎪0.28125⋅\alphaₛ ⋅│g_{hbb}⋅m_b⋅⎜m_S  + ───────────────────────────────────────
# ⎪                 │            ⎝                              4
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪
# ⎩                                                                            π
#
#                                                             2
#   2⎛m_S ⎞⎞              ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞│
# in ⎜────⎟⎟ + g_{htt}⋅mₜ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟│
#    ⎝2⋅mₜ⎠⎠              ⎝                           ⎝2⋅mₜ⎠⎠│
# ─────────────────────────────────────────────────────────────
# 3    5
#  ⋅m_S
#
#
# ________⎞⎞              ⎛                             ⎛         ______________
#       2 ⎟⎟              ⎜                             ⎜        ╱    2       2
# - 4⋅mₜ  ⎟⎟              ⎜        2 ⎛   2       2⎞    2⎜m_S + ╲╱  m_S  - 4⋅mₜ
# ────────⎟⎟              ⎜       π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜───────────────────────
# ________⎟⎟              ⎜                             ⎜         ______________
#       2 ⎟⎟              ⎜                             ⎜        ╱    2       2
# - 4⋅mₜ  ⎠⎟              ⎜   2                         ⎝m_S - ╲╱  m_S  - 4⋅mₜ
# ─────────⎟ + g_{htt}⋅mₜ⋅⎜m_S  + ──────────────────────────────────────────────
#          ⎠              ⎝                              4
# ──────────────────────────────────────────────────────────────────────────────
# 3    5
#  ⋅m_S
#
#
#
#               2
#            m_S
#       for ───── ≤ 1
#               2
#           4⋅mₜ
#
#    2
# ⎞⎞│
# ⎟⎟│
# ⎟⎟│
# ⎟⎟│
# ⎟⎟│
# ⎟⎟│
# ⎠⎟│
# ─⎟│
#  ⎠│
# ────    otherwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:59: RuntimeWarning: invalid value encountered in arcsin
#   return np.arcsin(np.sqrt((mS**2)/(4*mtop**2)))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2

# %%
Aht(ghtt,mS).simplify()
Aht(0.1,np.linspace(120,130,10))
# Out:
# ⎧                2 ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞
# ⎪           32⋅mₜ ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟                     2
# ⎪                  ⎝                           ⎝2⋅mₜ⎠⎠                  m_S
# ⎪           ──────────────────────────────────────────             for ───── ≤
# ⎪                                  4                                       2
# ⎪                             3⋅m_S                                    4⋅mₜ
# ⎪
# ⎪       ⎛                             ⎛          ______________⎞⎞
# ⎪       ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎨       ⎜        2 ⎛   2       2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟⎟
# ⎪       ⎜       π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪       ⎜                             ⎜          ______________⎟⎟
# ⎪       ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎪     2 ⎜   2                         ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠⎟
# ⎪32⋅mₜ ⋅⎜m_S  + ────────────────────────────────────────────────⎟
# ⎪       ⎝                              4                        ⎠
# ⎪────────────────────────────────────────────────────────────────    otherwise
# ⎪                                  4
# ⎩                             3⋅m_S
#
#
#
#
#  1
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([1.8301544801535439, 1.8311816309484925, 1.8322203406115005,
#        1.8332706750853873, 1.8343327013494153, 1.835406487434937,
#        1.8364921024413272, 1.8375896165523466, 1.8386991010528941,
#        1.839820628346068], dtype=object)

# %%
Ahb(ghbb,mS).simplify()
Ahb(0.1,np.linspace(120,130,10))
# Out:
# ⎧               2 ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞
# ⎪           8⋅mₜ ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟                     2
# ⎪                 ⎝                           ⎝2⋅mₜ⎠⎠                  m_S
# ⎪           ─────────────────────────────────────────             for ───── ≤
# ⎪                                  4                                      2
# ⎪                             3⋅m_S                                   4⋅mₜ
# ⎪
# ⎪      ⎛                             ⎛          ______________⎞⎞
# ⎪      ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎨      ⎜        2 ⎛   2       2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟⎟
# ⎪      ⎜       π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪      ⎜                             ⎜          ______________⎟⎟
# ⎪      ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎪    2 ⎜   2                         ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠⎟
# ⎪8⋅mₜ ⋅⎜m_S  + ────────────────────────────────────────────────⎟
# ⎪      ⎝                              4                        ⎠
# ⎪───────────────────────────────────────────────────────────────    otherwise
# ⎪                                  4
# ⎩                             3⋅m_S
#
#
#
#
# 1
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([0.45753862003838597, 0.45779540773712313, 0.45805508515287513,
#        0.45831766877134683, 0.4585831753373538, 0.45885162185873424,
#        0.4591230256103318, 0.45939740413808666, 0.45967477526322353,
#        0.459955157086517], dtype=object)

# %%
Af(ghtt,ghbb,mS).simplify()
Af(0.1,0.1,np.linspace(120,130,10))
# Out:
# ⎧                2 ⎛   2   ⎛   2       2⎞     2⎛m_S ⎞⎞
# ⎪           40⋅mₜ ⋅⎜m_S  + ⎝m_S  - 4⋅mₜ ⎠⋅asin ⎜────⎟⎟                     2
# ⎪                  ⎝                           ⎝2⋅mₜ⎠⎠                  m_S
# ⎪           ──────────────────────────────────────────             for ───── ≤
# ⎪                                  4                                       2
# ⎪                             3⋅m_S                                    4⋅mₜ
# ⎪
# ⎪       ⎛                             ⎛          ______________⎞⎞
# ⎪       ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎨       ⎜        2 ⎛   2       2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅mₜ  ⎟⎟
# ⎪       ⎜       π ⋅⎝m_S  - 4⋅mₜ ⎠⋅log ⎜────────────────────────⎟⎟
# ⎪       ⎜                             ⎜          ______________⎟⎟
# ⎪       ⎜                             ⎜         ╱    2       2 ⎟⎟
# ⎪     2 ⎜   2                         ⎝-m_S + ╲╱  m_S  - 4⋅mₜ  ⎠⎟
# ⎪40⋅mₜ ⋅⎜m_S  + ────────────────────────────────────────────────⎟
# ⎪       ⎝                              4                        ⎠
# ⎪────────────────────────────────────────────────────────────────    otherwise
# ⎪                                  4
# ⎩                             3⋅m_S
#
#
#
#
#  1
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# array([2.28769310019193, 2.2889770386856156, 2.2902754257643756,
#        2.291588343856734, 2.292915876686769, 2.294258109293671,
#        2.295615128051659, 2.2969870206904335, 2.2983738763161177,
#        2.299775785432585], dtype=object)

# %%
fW(mS)
#Esta función no esta definda en este rango 
fW(np.linspace(120,130,10))
# Out:
#        ⎛      ____________    ⎞
#        ⎜     ╱          2     ⎟
#        ⎜    ╱      4⋅m_W      ⎟
#        ⎜   ╱   1 - ──────  + 1⎟
#        ⎜  ╱            2      ⎟
#  2    2⎜╲╱          m_S       ⎟
# π ⋅log ⎜──────────────────────⎟
#        ⎜          ____________⎟
#        ⎜         ╱          2 ⎟
#        ⎜        ╱      4⋅m_W  ⎟
#        ⎜1 -    ╱   1 - ────── ⎟
#        ⎜      ╱            2  ⎟
#        ⎝    ╲╱          m_S   ⎠
# ───────────────────────────────
#                4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
gW(mS)
gW(np.linspace(120,130,10))
# Out:
#     2⎛ m_S ⎞
# asin ⎜─────⎟
#      ⎝2⋅m_W⎠
# array([0.71019667, 0.72791606, 0.74607247, 0.76468432, 0.78377145,
#        0.80335522, 0.82345874, 0.84410703, 0.86532726, 0.887149  ])

# %%
AW(mS)
AW(np.linspace(120,130,10))
# Out:
# ⎧                                         2
# ⎪             2⎛ m_S ⎞                 m_S
# ⎪         asin ⎜─────⎟            for ────── ≤ 1
# ⎪              ⎝2⋅m_W⎠                     2
# ⎪                                     4⋅m_W
# ⎪
# ⎪       ⎛      ____________    ⎞
# ⎪       ⎜     ╱          2     ⎟
# ⎪       ⎜    ╱      4⋅m_W      ⎟
# ⎪       ⎜   ╱   1 - ──────  + 1⎟
# ⎨       ⎜  ╱            2      ⎟
# ⎪ 2    2⎜╲╱          m_S       ⎟
# ⎪π ⋅log ⎜──────────────────────⎟
# ⎪       ⎜          ____________⎟
# ⎪       ⎜         ╱          2 ⎟
# ⎪       ⎜        ╱      4⋅m_W  ⎟
# ⎪       ⎜1 -    ╱   1 - ────── ⎟
# ⎪       ⎜      ╱            2  ⎟
# ⎪       ⎝    ╲╱          m_S   ⎠
# ⎪───────────────────────────────    otherwise
# ⎩               4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# array([0.7101966700234749, 0.7279160590442119, 0.7460724661334626,
#        0.7646843197590029, 0.7837714464586051, 0.8033552221146384,
#        0.8234587449421369, 0.8441070341223426, 0.8653272588836893,
#        0.8871490039320329], dtype=object)

# %%
FW(mS).simplify()
FW(np.linspace(120,130,10))
# Out:
# ⎧            ⎛     4        2 ⎛     2     ⎛   2        2⎞     2⎛ m_S ⎞⎞⎞
# ⎪          2⋅⎜- m_S  + 6⋅m_W ⋅⎜- m_S  - 2⋅⎝m_S  - 2⋅m_W ⎠⋅asin ⎜─────⎟⎟⎟
# ⎪            ⎝                ⎝                                ⎝2⋅m_W⎠⎠⎠
# ⎪          ─────────────────────────────────────────────────────────────
# ⎪                                          4
# ⎪                                       m_S
# ⎪
# ⎪  ⎛                ⎛                                ⎛          ______________
# ⎪  ⎜                ⎜                                ⎜         ╱    2        2
# ⎨  ⎜                ⎜          2 ⎛   2        2⎞    2⎜-m_S - ╲╱  m_S  - 4⋅m_W
# ⎪  ⎜                ⎜         π ⋅⎝m_S  - 2⋅m_W ⎠⋅log ⎜────────────────────────
# ⎪  ⎜                ⎜                                ⎜          ______________
# ⎪  ⎜                ⎜                                ⎜         ╱    2        2
# ⎪  ⎜     4        2 ⎜     2                          ⎝-m_S + ╲╱  m_S  - 4⋅m_W
# ⎪2⋅⎜- m_S  + 6⋅m_W ⋅⎜- m_S  - ────────────────────────────────────────────────
# ⎪  ⎝                ⎝                                 2
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                          4
# ⎩                                       m_S
#
#
#               2
#            m_S
#       for ────── ≤ 1
#                2
#           4⋅m_W
#
# _⎞⎞⎞
#  ⎟⎟⎟
#  ⎟⎟⎟
# ─⎟⎟⎟
# _⎟⎟⎟
#  ⎟⎟⎟
#  ⎠⎟⎟
# ──⎟⎟
#   ⎠⎠
# ────    otherwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# array([-8.169134589922486, -8.201806055442322, -8.235472696858885,
#        -8.270183781778385, -8.305992504320612, -8.34295642089809,
#        -8.381137949394951, -8.420604943318711, -8.461431355071872,
#        -8.503698005746127], dtype=object)

# %%
ghWW = sp.symbols('g_{hWW}',real=True)
AhW(ghWW,mS).simplify()
AhW(0.1,np.linspace(120,130,10))
# Out:
# ⎧                     ⎛   4        2 ⎛   2     ⎛   2        2⎞     2⎛ m_S ⎞⎞⎞
# ⎪          -2⋅g_{hWW}⋅⎜m_S  + 6⋅m_W ⋅⎜m_S  + 2⋅⎝m_S  - 2⋅m_W ⎠⋅asin ⎜─────⎟⎟⎟
# ⎪                     ⎝              ⎝                              ⎝2⋅m_W⎠⎠⎠
# ⎪          ───────────────────────────────────────────────────────────────────
# ⎪                                           4
# ⎪                                        m_S ⋅m_W
# ⎪
# ⎪           ⎛              ⎛                              ⎛          _________
# ⎪           ⎜              ⎜                              ⎜         ╱    2
# ⎨           ⎜              ⎜        2 ⎛   2        2⎞    2⎜-m_S - ╲╱  m_S  - 4
# ⎪           ⎜              ⎜       π ⋅⎝m_S  - 2⋅m_W ⎠⋅log ⎜───────────────────
# ⎪           ⎜              ⎜                              ⎜          _________
# ⎪           ⎜              ⎜                              ⎜         ╱    2
# ⎪           ⎜   4        2 ⎜   2                          ⎝-m_S + ╲╱  m_S  - 4
# ⎪-2⋅g_{hWW}⋅⎜m_S  + 6⋅m_W ⋅⎜m_S  + ───────────────────────────────────────────
# ⎪           ⎝              ⎝                               2
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                           4
# ⎩                                        m_S ⋅m_W
#
#
#                     2
#                  m_S
#             for ────── ≤ 1
#                      2
#                 4⋅m_W
#
# ______⎞⎞⎞
#     2 ⎟⎟⎟
# ⋅m_W  ⎟⎟⎟
# ──────⎟⎟⎟
# ______⎟⎟⎟
#     2 ⎟⎟⎟
# ⋅m_W  ⎠⎟⎟
# ───────⎟⎟
#        ⎠⎠
# ──────────    otherwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# array([-0.010163269746976804, -0.010203916514813971, -0.01024580138700268,
#        -0.01028898565766977, -0.010333535505941367, -0.010379522538098372,
#        -0.010427024408607908, -0.01047612553442903, -0.010526917920192926,
#        -0.01057950211590854], dtype=object)

# %%
mCH = sp.symbols(r'm_{H^{\pm}}',positive=True)
fH(mCH,mS).simplify()
fH(200.0,np.linspace(120,130,10))
# Out:
#        ⎛          ________________________⎞
#        ⎜         ╱    2                 2 ⎟
#  2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟
# π ⋅log ⎜──────────────────────────────────⎟
#        ⎜          ________________________⎟
#        ⎜         ╱    2                 2 ⎟
#        ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠
# ───────────────────────────────────────────
#                      4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], dtype=object)

# %%
gH(mCH,mS)
gH(200.0,np.linspace(120,130,10))
# Out:
#     2⎛     m_S      ⎞
# asin ⎜──────────────⎟
#      ⎝2⋅m_{H__{\pm}}⎠
# array([0.09283761, 0.09462139, 0.09642381, 0.09824495, 0.10008488,
#        0.10194366, 0.10382137, 0.10571807, 0.10763385, 0.10956876])

# %%
AH(mCH,mS).simplify()
AH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                                                          2
# ⎪               2⎛     m_S      ⎞                       m_S
# ⎪           asin ⎜──────────────⎟             for ─────────────── ≤ 1
# ⎪                ⎝2⋅m_{H__{\pm}}⎠                               2
# ⎪                                                 4⋅m_{H__{\pm}}
# ⎪
# ⎪       ⎛          ________________________⎞
# ⎨       ⎜         ╱    2                 2 ⎟
# ⎪ 2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎟
# ⎪π ⋅log ⎜──────────────────────────────────⎟
# ⎪       ⎜          ________________________⎟
# ⎪       ⎜         ╱    2                 2 ⎟
# ⎪       ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\pm}}  ⎠
# ⎪───────────────────────────────────────────         otherwise
# ⎩                     4
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([0.09283761341094673, 0.09462138662287439, 0.09642380980419445,
#        0.09824495046738933, 0.10008487708040625, 0.10194365907824048,
#        0.10382136687475073, 0.10571807187471097, 0.1076338464861039,
#        0.10956876413266105], dtype=object)

# %%
FH(mCH,mS).simplify()
FH(200.0,np.linspace(120,130,10))
# Out:
# ⎧                        2 ⎛     2                 2     2⎛     m_S      ⎞⎞
# ⎪          4⋅m_{H__{\pm}} ⋅⎜- m_S  + 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                          ⎝                              ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪          ────────────────────────────────────────────────────────────────
# ⎪                                           4
# ⎪                                        m_S
# ⎪
# ⎪                ⎛                              ⎛          ___________________
# ⎨                ⎜                              ⎜         ╱    2
# ⎪              2 ⎜     2    2             2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{\p
# ⎪4⋅m_{H__{\pm}} ⋅⎜- m_S  + π ⋅m_{H__{\pm}} ⋅log ⎜─────────────────────────────
# ⎪                ⎜                              ⎜          ___________________
# ⎪                ⎜                              ⎜         ╱    2
# ⎪                ⎝                              ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{\p
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                           4
# ⎩                                        m_S
#
#
#                       2
#                    m_S
#          for ─────────────── ≤ 1
#                            2
#              4⋅m_{H__{\pm}}
#
# _____⎞⎞
#    2 ⎟⎟
# m}}  ⎟⎟
# ─────⎟⎟
# _____⎟⎟
#    2 ⎟⎟
# m}}  ⎠⎠
# ───────         otherwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([0.3503226433267578, 0.3506587843664095, 0.3509988203047495,
#        0.35134277627047816, 0.3516906777863637, 0.3520425507750452,
#        0.3523984215649768, 0.35275831689649734, 0.3531222639280239,
#        0.3534902902423687], dtype=object)

# %%
gCH = sp.symbols(r'g_{H^{\pm}}',real=True)
AHc(gCH,mCH,mS).simplify()
AHc(0.3,200.0,np.linspace(120,130,10))
# Out:
# ⎧                              ⎛   2                 2     2⎛     m_S      ⎞⎞
# ⎪          -4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  - 4⋅m_{H__{\pm}} ⋅asin ⎜──────────────⎟⎟
# ⎪                              ⎝                            ⎝2⋅m_{H__{\pm}}⎠⎠
# ⎪          ───────────────────────────────────────────────────────────────────
# ⎪                                             4
# ⎪                                          m_S
# ⎪
# ⎪                    ⎛                            ⎛          _________________
# ⎨                    ⎜                            ⎜         ╱    2
# ⎪                    ⎜   2    2             2    2⎜-m_S - ╲╱  m_S  - 4⋅m_{H__{
# ⎪-4⋅g_{H__{\pm}}⋅m_W⋅⎜m_S  - π ⋅m_{H__{\pm}} ⋅log ⎜───────────────────────────
# ⎪                    ⎜                            ⎜          _________________
# ⎪                    ⎜                            ⎜         ╱    2
# ⎪                    ⎝                            ⎝-m_S + ╲╱  m_S  - 4⋅m_{H__{
# ⎪─────────────────────────────────────────────────────────────────────────────
# ⎪                                             4
# ⎩                                          m_S
#
#
#                          2
#                       m_S
#             for ─────────────── ≤ 1
#                               2
#                 4⋅m_{H__{\pm}}
#
# _______⎞⎞
#      2 ⎟⎟
# \pm}}  ⎟⎟
# ───────⎟⎟
# _______⎟⎟
#      2 ⎟⎟
# \pm}}  ⎠⎠
# ──────────         otherwise
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([0.000211189378109711, 0.00021139201821440725,
#        0.00021159700632956597, 0.00021180435760383576,
#        0.00021201408742342598, 0.00021222621141560522,
#        0.00021244074545228456, 0.00021265770565367673,
#        0.0002128771083920298, 0.0002130989702954352], dtype=object)

# %%
Ahgaga(ghtt,ghbb,ghWW,gCH,mCH,mS).simplify()
Ahgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#                                     ⎛                  ⎛⎧
#                                     ⎜                  ⎜⎪               2⎛
#                                     ⎜                  ⎜⎪           asin ⎜────
#                                     ⎜                  ⎜⎪                ⎝2⋅m_
#                                     ⎜                  ⎜⎪
#                                     ⎜                  ⎜⎪
#                                     ⎜                  ⎜⎪       ⎛ ⎛      _____
#                                     ⎜                  ⎜⎪       ⎜ ⎜     ╱
#                                     ⎜         2        ⎜⎪       ⎜ ⎜    ╱
#                                   2 ⎜      m_S         ⎜⎪       ⎜-⎜   ╱   1 -
#   16⋅g_{H__{\pm}}⋅m_W⋅m_{H__{\pm}} ⋅⎜─────────────── - ⎜⎨       ⎜ ⎜  ╱
#                                     ⎜              2   ⎜⎪ 2    2⎜ ⎝╲╱
#                                     ⎜4⋅m_{H__{\pm}}    ⎜⎪π ⋅log ⎜─────────────
#                                     ⎜                  ⎜⎪       ⎜        _____
#                                     ⎜                  ⎜⎪       ⎜       ╱
#                                     ⎜                  ⎜⎪       ⎜      ╱
#                                     ⎜                  ⎜⎪       ⎜     ╱   1 -
#                                     ⎜                  ⎜⎪       ⎜    ╱
#                                     ⎜                  ⎜⎪       ⎝  ╲╱
#                                     ⎜                  ⎜⎪─────────────────────
#                                     ⎝                  ⎝⎩
# - ────────────────────────────────────────────────────────────────────────────
#                                                                   4
#                                                                m_S
#
#                                       2         ⎞⎞                   ⎛
#  m_S      ⎞                        m_S          ⎟⎟                   ⎜
# ──────────⎟              for ─────────────── ≤ 1⎟⎟                   ⎜
# {H__{\pm}}⎠                                2    ⎟⎟                   ⎜
#                              4⋅m_{H__{\pm}}     ⎟⎟                   ⎜
#                                                 ⎟⎟                   ⎜
# ________________    ⎞ ⎞                         ⎟⎟                   ⎜
#               2     ⎟ ⎟                         ⎟⎟                   ⎜
# 4⋅m_{H__{\pm}}      ⎟ ⎟                         ⎟⎟                   ⎜    4
# ───────────────  + 1⎟ ⎟                         ⎟⎟                 3 ⎜ m_S
#          2          ⎟ ⎟                         ⎟⎟   16⋅g_{hWW}⋅m_W ⋅⎜────── +
#       m_S           ⎠ ⎟                         ⎟⎟                   ⎜     4
# ──────────────────────⎟                         ⎟⎟                   ⎜8⋅m_W
# ________________      ⎟                         ⎟⎟                   ⎜
#               2       ⎟                         ⎟⎟                   ⎜
# 4⋅m_{H__{\pm}}        ⎟                         ⎟⎟                   ⎜
# ───────────────  - 1  ⎟                         ⎟⎟                   ⎜
#          2            ⎟                         ⎟⎟                   ⎜
#       m_S             ⎠                         ⎟⎟                   ⎜
# ───────────────────────         otherwise       ⎟⎟                   ⎜
# 4                                               ⎠⎠                   ⎝
# ────────────────────────────────────────────────── - ─────────────────────────
#
#
#
#                        ⎛⎧                                             2     ⎞⎞
#                        ⎜⎪               2⎛ m_S ⎞                   m_S      ⎟⎟
#                        ⎜⎪           asin ⎜─────⎟              for ────── ≤ 1⎟⎟
#                        ⎜⎪                ⎝2⋅m_W⎠                       2    ⎟⎟
#                        ⎜⎪                                         4⋅m_W     ⎟⎟
#                        ⎜⎪                                                   ⎟⎟
#                        ⎜⎪       ⎛ ⎛      ____________    ⎞ ⎞                ⎟⎟
#                        ⎜⎪       ⎜ ⎜     ╱          2     ⎟ ⎟                ⎟⎟
#       2   ⎛     2    ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅m_W      ⎟ ⎟                ⎟⎟
#  3⋅m_S    ⎜3⋅m_S     ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ──────  + 1⎟ ⎟                ⎟⎟
#  ────── + ⎜────── - 3⎟⋅⎜⎨       ⎜ ⎜  ╱            2      ⎟ ⎟                ⎟⎟
#       2   ⎜     2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          m_S       ⎠ ⎟                ⎟⎟
#  4⋅m_W    ⎝2⋅m_W     ⎠ ⎜⎪π ⋅log ⎜──────────────────────────⎟                ⎟⎟
#                        ⎜⎪       ⎜        ____________      ⎟                ⎟⎟
#                        ⎜⎪       ⎜       ╱          2       ⎟                ⎟⎟
#                        ⎜⎪       ⎜      ╱      4⋅m_W        ⎟                ⎟⎟
#                        ⎜⎪       ⎜     ╱   1 - ──────  - 1  ⎟                ⎟⎟
#                        ⎜⎪       ⎜    ╱            2        ⎟                ⎟⎟
#                        ⎜⎪       ⎝  ╲╱          m_S         ⎠                ⎟⎟
#                        ⎜⎪───────────────────────────────────    otherwise   ⎟⎟
#                        ⎝⎩                 4                                 ⎠⎠
# ──────────────────────────────────────────────────────────────────────────────
#                             4
#                          m_S
#
#           ⎛                      ⎛⎧
#           ⎜                      ⎜⎪               2⎛m_S ⎞                   m_
#           ⎜                      ⎜⎪           asin ⎜────⎟              for ───
#           ⎜                      ⎜⎪                ⎝2⋅mₜ⎠
#           ⎜                      ⎜⎪                                        4⋅m
#           ⎜                      ⎜⎪
#           ⎜                      ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞
#           ⎜                      ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟
#           ⎜    2     ⎛    2    ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟
#         4 ⎜ m_S      ⎜ m_S     ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟
#    80⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱            2     ⎟ ⎟
#           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          m_S      ⎠ ⎟
#           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟
#           ⎜                      ⎜⎪       ⎜        ___________      ⎟
#           ⎜                      ⎜⎪       ⎜       ╱         2       ⎟
#           ⎜                      ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟
#           ⎜                      ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟
#           ⎜                      ⎜⎪       ⎜    ╱            2       ⎟
#           ⎜                      ⎜⎪       ⎝  ╲╱          m_S        ⎠
#           ⎜                      ⎜⎪──────────────────────────────────    other
#           ⎝                      ⎝⎩                4
#  + ───────────────────────────────────────────────────────────────────────────
#                                                4
#                                           3⋅m_S
#
#  2    ⎞⎞
# S     ⎟⎟
# ── ≤ 1⎟⎟
#  2    ⎟⎟
# ₜ     ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
#       ⎟⎟
# wise  ⎟⎟
#       ⎠⎠
# ────────
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([2.2472512105821325, 2.248372764644574, 2.249503817222694,
#        2.250644205583659, 2.251793748750427, 2.2529522453526933,
#        2.2541194711626797, 2.2552951762583713, 2.256479081743738,
#        2.2576708759392465], dtype=object)

# %%
WidthHgaga(ghtt,ghbb,ghWW,gCH,mCH,mS).simplify()
WidthHgaga(0.1,0.2,0.4,0.3,200.0,np.linspace(120,130,10))
# Out:
#
#                  │                                    ⎛                  ⎛⎧
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜         2        ⎜⎪
#                  │                                  2 ⎜      m_S         ⎜⎪
#                  │  16⋅g_{H__{\pm}}⋅m_W⋅m_{H__{\pm}} ⋅⎜─────────────── - ⎜⎨
#                  │                                    ⎜              2   ⎜⎪ 2
#                  │                                    ⎜4⋅m_{H__{\pm}}    ⎜⎪π ⋅
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪
#                  │                                    ⎜                  ⎜⎪───
#           2    3 │                                    ⎝                  ⎝⎩
# \alpha_{e} ⋅m_S ⋅│- ──────────────────────────────────────────────────────────
#                  │
#                  │
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                     2         ⎞⎞
#           2⎛     m_S      ⎞                      m_S          ⎟⎟
#       asin ⎜──────────────⎟            for ─────────────── ≤ 1⎟⎟
#            ⎝2⋅m_{H__{\pm}}⎠                              2    ⎟⎟
#                                            4⋅m_{H__{\pm}}     ⎟⎟
#                                                               ⎟⎟
#     ⎛      _____________________    ⎞                         ⎟⎟
#     ⎜     ╱                   2     ⎟                         ⎟⎟
#     ⎜    ╱      4⋅m_{H__{\pm}}      ⎟                         ⎟⎟
#     ⎜   ╱   1 - ───────────────  + 1⎟                         ⎟⎟
#     ⎜  ╱                 2          ⎟                         ⎟⎟   16⋅g_{hWW}⋅
#    2⎜╲╱               m_S           ⎟                         ⎟⎟
# log ⎜───────────────────────────────⎟                         ⎟⎟
#     ⎜          _____________________⎟                         ⎟⎟
#     ⎜         ╱                   2 ⎟                         ⎟⎟
#     ⎜        ╱      4⋅m_{H__{\pm}}  ⎟                         ⎟⎟
#     ⎜1 -    ╱   1 - ─────────────── ⎟                         ⎟⎟
#     ⎜      ╱                 2      ⎟                         ⎟⎟
#     ⎝    ╲╱               m_S       ⎠                         ⎟⎟
# ─────────────────────────────────────         otherwise       ⎟⎟
#                 4                                             ⎠⎠
# ──────────────────────────────────────────────────────────────── - ───────────
#     4
#  m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#      ⎛                               ⎛⎧
#      ⎜                               ⎜⎪             2⎛ m_S ⎞                 m
#      ⎜                               ⎜⎪         asin ⎜─────⎟            for ──
#      ⎜                               ⎜⎪              ⎝2⋅m_W⎠
#      ⎜                               ⎜⎪                                     4⋅
#      ⎜                               ⎜⎪
#      ⎜                               ⎜⎪       ⎛      ____________    ⎞
#      ⎜                               ⎜⎪       ⎜     ╱          2     ⎟
#      ⎜    4         2   ⎛     2    ⎞ ⎜⎪       ⎜    ╱      4⋅m_W      ⎟
#    3 ⎜ m_S     3⋅m_S    ⎜3⋅m_S     ⎟ ⎜⎪       ⎜   ╱   1 - ──────  + 1⎟
# m_W ⋅⎜────── + ────── + ⎜────── - 3⎟⋅⎜⎨       ⎜  ╱            2      ⎟
#      ⎜     4        2   ⎜     2    ⎟ ⎜⎪ 2    2⎜╲╱          m_S       ⎟
#      ⎜8⋅m_W    4⋅m_W    ⎝2⋅m_W     ⎠ ⎜⎪π ⋅log ⎜──────────────────────⎟
#      ⎜                               ⎜⎪       ⎜          ____________⎟
#      ⎜                               ⎜⎪       ⎜         ╱          2 ⎟
#      ⎜                               ⎜⎪       ⎜        ╱      4⋅m_W  ⎟
#      ⎜                               ⎜⎪       ⎜1 -    ╱   1 - ────── ⎟
#      ⎜                               ⎜⎪       ⎜      ╱            2  ⎟
#      ⎜                               ⎜⎪       ⎝    ╲╱          m_S   ⎠
#      ⎜                               ⎜⎪───────────────────────────────    othe
#      ⎝                               ⎝⎩               4
# ──────────────────────────────────────────────────────────────────────────────
#                                         4
#                                      m_S
# ──────────────────────────────────────────────────────────────────────────────
#           3    2
#     1024⋅π ⋅m_W
#
#
#   2     ⎞⎞          ⎛                      ⎛⎧
# _S      ⎟⎟          ⎜                      ⎜⎪               2⎛m_S ⎞
# ──── ≤ 1⎟⎟          ⎜                      ⎜⎪           asin ⎜────⎟
#    2    ⎟⎟          ⎜                      ⎜⎪                ⎝2⋅mₜ⎠
# m_W     ⎟⎟          ⎜                      ⎜⎪
#         ⎟⎟          ⎜                      ⎜⎪
#         ⎟⎟          ⎜                      ⎜⎪       ⎛ ⎛      ___________    ⎞
#         ⎟⎟          ⎜                      ⎜⎪       ⎜ ⎜     ╱         2     ⎟
#         ⎟⎟          ⎜    2     ⎛    2    ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟
#         ⎟⎟        4 ⎜ m_S      ⎜ m_S     ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟
#         ⎟⎟   80⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱            2     ⎟
#         ⎟⎟          ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          m_S      ⎠
#         ⎟⎟          ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜─────────────────────────
#         ⎟⎟          ⎜                      ⎜⎪       ⎜        ___________
#         ⎟⎟          ⎜                      ⎜⎪       ⎜       ╱         2
#         ⎟⎟          ⎜                      ⎜⎪       ⎜      ╱      4⋅mₜ
#         ⎟⎟          ⎜                      ⎜⎪       ⎜     ╱   1 - ─────  - 1
#         ⎟⎟          ⎜                      ⎜⎪       ⎜    ╱            2
#         ⎟⎟          ⎜                      ⎜⎪       ⎝  ╲╱          m_S
# rwise   ⎟⎟          ⎜                      ⎜⎪─────────────────────────────────
#         ⎠⎠          ⎝                      ⎝⎩                4
# ────────── + ─────────────────────────────────────────────────────────────────
#                                                          4
#                                                     3⋅m_S
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                    2
#            2    ⎞⎞│
#         m_S     ⎟⎟│
#    for ───── ≤ 1⎟⎟│
#            2    ⎟⎟│
#        4⋅mₜ     ⎟⎟│
#                 ⎟⎟│
# ⎞               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎟               ⎟⎟│
# ⎠               ⎟⎟│
# ─    otherwise  ⎟⎟│
#                 ⎠⎠│
# ──────────────────│
#                   │
#                   │
# ────────────────────
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([2.2653894354684108e-06, 2.3312265678606318e-06,
#        2.3983904306123735e-06, 2.4668968141792183e-06,
#        2.5367615394221425e-06, 2.6080004462569665e-06,
#        2.680629380387015e-06, 2.7546641777760156e-06,
#        2.830120646443531e-06, 2.9070145450716285e-06], dtype=object)

# %%
RTW(mS).simplify()
RTW(np.linspace(120,130,10))
# Out:
#                                                                            ___
#                                                                           ╱
#                                                                          ╱   m
#                                                                         ╱    ─
#                                           ⎛     ⎛   2        2⎞ ⎞      ╱
#      2 ⎛   4        2    2         4⎞     ⎜-m_S⋅⎝m_S  - 3⋅m_W ⎠ ⎟     ╱      m
# 6⋅m_W ⋅⎝m_S  - 8⋅m_S ⋅m_W  + 20⋅m_W ⎠⋅acos⎜─────────────────────⎟ - ╲╱      4
#                                           ⎜             3       ⎟
#                                           ⎝        2⋅m_W        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ________                                                          ___________
#   2                                                              ╱     2
# _W                                                              ╱   m_W
# ───                                                            ╱    ────
#   2                                                           ╱        2
# _S       ⎛   2      2⎞ ⎛     4         2    2         4⎞     ╱      m_S
#     - 1 ⋅⎝m_S  - m_W ⎠⋅⎝2⋅m_S  - 13⋅m_S ⋅m_W  + 47⋅m_W ⎠ - ╲╱      4     - 1 ⋅
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                             ___________
#                            ╱     2
#                           ╱   m_W
#                          ╱    ────
#                         ╱        2
#               4    2   ╱      m_S
#          2⋅m_S ⋅m_W ⋅╲╱      4     - 1
#
#
#
#    ⎛           2 ⎛   4        2    2        4⎞⎞
#    ⎜      3⋅m_W ⋅⎝m_S  - 6⋅m_S ⋅m_W  + 4⋅m_W ⎠⎟
#    ⎜⎛   2⎞                                    ⎟
#    ⎜⎜m_W ⎟                                    ⎟
# log⎜⎜────⎟                                    ⎟
#    ⎜⎜   2⎟                                    ⎟
#    ⎝⎝m_S ⎠                                    ⎠
# ───────────────────────────────────────────────
# array([-0.08142428, -0.10491518, -0.12832073, -0.15151597, -0.17437759,
#        -0.19678384, -0.21861431, -0.2397497 , -0.26007151, -0.27946176])

# %%
RTZ(mS).simplify()
RTZ(np.linspace(120,130,10))
# Out:
#                                                                            ___
#                                                                           ╱
#                                                                          ╱   m
#                                                                         ╱    ─
#                                           ⎛     ⎛   2        2⎞ ⎞      ╱
#      2 ⎛   4        2    2         4⎞     ⎜-m_S⋅⎝m_S  - 3⋅m_Z ⎠ ⎟     ╱      m
# 6⋅m_Z ⋅⎝m_S  - 8⋅m_S ⋅m_Z  + 20⋅m_Z ⎠⋅acos⎜─────────────────────⎟ - ╲╱      4
#                                           ⎜             3       ⎟
#                                           ⎝        2⋅m_Z        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
# ________                                                          ___________
#   2                                                              ╱     2
# _Z                                                              ╱   m_Z
# ───                                                            ╱    ────
#   2                                                           ╱        2
# _S       ⎛   2      2⎞ ⎛     4         2    2         4⎞     ╱      m_S
#     - 1 ⋅⎝m_S  - m_Z ⎠⋅⎝2⋅m_S  - 13⋅m_S ⋅m_Z  + 47⋅m_Z ⎠ - ╲╱      4     - 1 ⋅
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                             ___________
#                            ╱     2
#                           ╱   m_Z
#                          ╱    ────
#                         ╱        2
#               4    2   ╱      m_S
#          2⋅m_S ⋅m_Z ⋅╲╱      4     - 1
#
#
#
#    ⎛           2 ⎛   4        2    2        4⎞⎞
#    ⎜      3⋅m_Z ⋅⎝m_S  - 6⋅m_S ⋅m_Z  + 4⋅m_Z ⎠⎟
#    ⎜⎛   2⎞                                    ⎟
#    ⎜⎜m_Z ⎟                                    ⎟
# log⎜⎜────⎟                                    ⎟
#    ⎜⎜   2⎟                                    ⎟
#    ⎝⎝m_S ⎠                                    ⎠
# ───────────────────────────────────────────────
# array([0.16964468, 0.15835025, 0.14578711, 0.1320438 , 0.11721097,
#        0.10138073, 0.08464612, 0.0671007 , 0.04883813, 0.02995186])

# %%
δZ
# Out:
# 304.6635823627211

# %%
WidthHWW(ghWW,mS).simplify()
WidthHWW(0.3,np.linspace(120,130,10))
# Out:
#          ⎛
#          ⎜
#          ⎜
#          ⎜
#          ⎜                                          ⎛     ⎛   2        2⎞ ⎞
#        2 ⎜     2 ⎛   4        2    2         4⎞     ⎜-m_S⋅⎝m_S  - 3⋅m_W ⎠ ⎟
# g_{hWW} ⋅⎜6⋅m_W ⋅⎝m_S  - 8⋅m_S ⋅m_W  + 20⋅m_W ⎠⋅acos⎜─────────────────────⎟ -
#          ⎜                                          ⎜             3       ⎟
#          ⎝                                          ⎝        2⋅m_W        ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#        ___________                                                          __
#       ╱     2                                                              ╱
#      ╱   m_W                                                              ╱
#     ╱    ────                                                            ╱
#    ╱        2                                                           ╱
#   ╱      m_S       ⎛   2      2⎞ ⎛     4         2    2         4⎞     ╱
# ╲╱      4     - 1 ⋅⎝m_S  - m_W ⎠⋅⎝2⋅m_S  - 13⋅m_S ⋅m_W  + 47⋅m_W ⎠ - ╲╱      4
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                     ___________
#                                    ╱     2
#                                   ╱   m_W
#                                  ╱    ────
#                                 ╱        2
#                  3    3    6   ╱      m_S
#            1024⋅π ⋅m_S ⋅m_W ⋅╲╱      4     - 1
#
# _________                                                ⎞
#    2                                                     ⎟
# m_W          ⎛           2 ⎛   4        2    2        4⎞⎞⎟
# ────         ⎜      3⋅m_W ⋅⎝m_S  - 6⋅m_S ⋅m_W  + 4⋅m_W ⎠⎟⎟
#    2         ⎜⎛   2⎞                                    ⎟⎟
# m_S          ⎜⎜m_W ⎟                                    ⎟⎟
#      - 1 ⋅log⎜⎜────⎟                                    ⎟⎟
#              ⎜⎜   2⎟                                    ⎟⎟
#              ⎝⎝m_S ⎠                                    ⎠⎠
# ──────────────────────────────────────────────────────────
# array([-1.32705137e-12, -1.72573800e-12, -2.13009780e-12, -2.53799879e-12,
#        -2.94726186e-12, -3.35565969e-12, -3.76091459e-12, -4.16069548e-12,
#        -4.55261364e-12, -4.93421735e-12])

# %%
ghZZ = sp.symbols('g_{HZZ}',real=True)
WidthHZZ(ghZZ,mS).simplify()
WidthHZZ(0.3,np.linspace(120,130,10))
# Out:
#                    ⎛
#                    ⎜
#                    ⎜
#                    ⎜
#                    ⎜                                            ⎛     ⎛   2
#                  2 ⎜       2 ⎛   4        2    2         4⎞     ⎜-m_S⋅⎝m_S  -
# -\delta_Z⋅g_{HZZ} ⋅⎜- 6⋅m_Z ⋅⎝m_S  - 8⋅m_S ⋅m_Z  + 20⋅m_Z ⎠⋅acos⎜─────────────
#                    ⎜                                            ⎜
#                    ⎝                                            ⎝        2⋅m_Z
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#                    ___________
#                   ╱     2
#                  ╱   m_Z
#                 ╱    ────
#      2⎞ ⎞      ╱        2
# 3⋅m_Z ⎠ ⎟     ╱      m_S       ⎛   2      2⎞ ⎛     4         2    2         4⎞
# ────────⎟ + ╲╱      4     - 1 ⋅⎝m_S  - m_Z ⎠⋅⎝2⋅m_S  - 13⋅m_S ⋅m_Z  + 47⋅m_Z ⎠
# 3       ⎟
#         ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                            ___________
#                                           ╱     2
#                                          ╱   m_Z
#                                         ╱    ────
#                                        ╱        2
#                         3    3    6   ╱      m_S
#                   4096⋅π ⋅m_S ⋅m_Z ⋅╲╱      4     - 1
#
#           ___________                                                ⎞
#          ╱     2                                                     ⎟
#         ╱   m_Z          ⎛           2 ⎛   4        2    2        4⎞⎞⎟
#        ╱    ────         ⎜      3⋅m_Z ⋅⎝m_S  - 6⋅m_S ⋅m_Z  + 4⋅m_Z ⎠⎟⎟
#       ╱        2         ⎜⎛   2⎞                                    ⎟⎟
#      ╱      m_S          ⎜⎜m_Z ⎟                                    ⎟⎟
#  + ╲╱      4     - 1 ⋅log⎜⎜────⎟                                    ⎟⎟
#                          ⎜⎜   2⎟                                    ⎟⎟
#                          ⎝⎝m_S ⎠                                    ⎠⎠
# ───────────────────────────────────────────────────────────────────────
# array([1.27134038e-10, 1.19768630e-10, 1.11278082e-10, 1.01704184e-10,
#        9.10928136e-11, 7.94935121e-11, 6.69591241e-11, 5.35454709e-11,
#        3.93110650e-11, 2.43168621e-11])

# %%
BRhfifj(ghtt,3,mb['symbol'],mb['symbol'])
BRhfifj(0.1,3.0,mb['value'],mb['value'])
# Out:
#                                             3/2
#                              ⎛        2    ⎞
#                         2    ⎜  16⋅m_b     ⎟
# 11.4329268292683⋅g_{htt} ⋅mₕ⋅⎜- ─────── + 4⎟
#                              ⎜      2      ⎟
#                              ⎝    mₕ       ⎠
# ───────────────────────────────────────────────
#                        π
# 36.20099475928305

# %%
BRhgaga(ghtt,ghbb,ghWW,gCH,mCH)
BRhgaga(0.1,0.2,0.3,0.11,np.linspace(200,300,10))
# Out:
#
#                                   │                                  ⎛
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                2 ⎜
#                                   │16⋅g_{H__{\pm}}⋅m_W⋅m_{H__{\pm}} ⋅⎜- ──────
#                                   │                                  ⎜
#                                   │                                  ⎜  4⋅m_{H
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                                   │                                  ⎜
#                             2   3 │                                  ⎝
# 0.238185975609756⋅\alpha_{e} ⋅mₕ ⋅│───────────────────────────────────────────
#                                   │
#                                   │
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#             ⎛⎧                                                      2
#             ⎜⎪             2⎛      mₕ      ⎞                      mₕ
#             ⎜⎪         asin ⎜──────────────⎟            for ─────────────── ≤
#             ⎜⎪              ⎝2⋅m_{H__{\pm}}⎠                              2
#             ⎜⎪                                              4⋅m_{H__{\pm}}
#             ⎜⎪
#             ⎜⎪       ⎛      _____________________    ⎞
#             ⎜⎪       ⎜     ╱                   2     ⎟
#   2         ⎜⎪       ⎜    ╱      4⋅m_{H__{\pm}}      ⎟
# mₕ          ⎜⎪       ⎜   ╱   1 - ───────────────  + 1⎟
# ───────── + ⎜⎨       ⎜  ╱                2           ⎟
#         2   ⎜⎪ 2    2⎜╲╱               mₕ            ⎟
# __{\pm}}    ⎜⎪π ⋅log ⎜───────────────────────────────⎟
#             ⎜⎪       ⎜          _____________________⎟
#             ⎜⎪       ⎜         ╱                   2 ⎟
#             ⎜⎪       ⎜        ╱      4⋅m_{H__{\pm}}  ⎟
#             ⎜⎪       ⎜1 -    ╱   1 - ─────────────── ⎟
#             ⎜⎪       ⎜      ╱                2       ⎟
#             ⎜⎪       ⎝    ╲╱               mₕ        ⎠
#             ⎜⎪────────────────────────────────────────         otherwise
#             ⎝⎩                   4
# ──────────────────────────────────────────────────────────────────────────────
#                    4
#                  mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#  ⎞⎞                   ⎛                ⎛⎧
#  ⎟⎟                   ⎜                ⎜⎪              2⎛  mₕ ⎞
# 1⎟⎟                   ⎜                ⎜⎪          asin ⎜─────⎟             fo
#  ⎟⎟                   ⎜                ⎜⎪               ⎝2⋅m_W⎠
#  ⎟⎟                   ⎜                ⎜⎪
#  ⎟⎟                   ⎜                ⎜⎪
#  ⎟⎟                   ⎜                ⎜⎪       ⎛      ______________    ⎞
#  ⎟⎟                   ⎜                ⎜⎪       ⎜     ╱        2         ⎟
#  ⎟⎟                   ⎜  ⎛         2 ⎞ ⎜⎪       ⎜    ╱    4⋅m_W          ⎟
#  ⎟⎟                 3 ⎜  ⎜     3⋅mₕ  ⎟ ⎜⎪       ⎜   ╱   - ────── + 1  + 1⎟
#  ⎟⎟   16⋅g_{hWW}⋅m_W ⋅⎜- ⎜-3 + ──────⎟⋅⎜⎨       ⎜  ╱         2           ⎟
#  ⎟⎟                   ⎜  ⎜          2⎟ ⎜⎪ 2    2⎜╲╱        mₕ            ⎟
#  ⎟⎟                   ⎜  ⎝     2⋅m_W ⎠ ⎜⎪π ⋅log ⎜────────────────────────⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎜          ______________⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎜         ╱        2     ⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎜        ╱    4⋅m_W      ⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎜1 -    ╱   - ────── + 1 ⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎜      ╱         2       ⎟
#  ⎟⎟                   ⎜                ⎜⎪       ⎝    ╲╱        mₕ        ⎠
#  ⎟⎟                   ⎜                ⎜⎪─────────────────────────────────
#  ⎠⎠                   ⎝                ⎝⎩                4
# ─── + ────────────────────────────────────────────────────────────────────────
#                                                           4
#                                                         mₕ
# ──────────────────────────────────────────────────────────────────────────────
#                 3    2
#                π ⋅m_W
#
#
#      2      ⎞                  ⎞          ⎛                      ⎛⎧
#    mₕ       ⎟                  ⎟          ⎜                      ⎜⎪
# r ────── ≤ 1⎟                  ⎟          ⎜                      ⎜⎪         as
#        2    ⎟                  ⎟          ⎜                      ⎜⎪
#   4⋅m_W     ⎟                  ⎟          ⎜                      ⎜⎪
#             ⎟                  ⎟          ⎜                      ⎜⎪
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎛
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜
#             ⎟       2       4  ⎟          ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜
#             ⎟   3⋅mₕ      mₕ   ⎟        4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜
#             ⎟ - ────── - ──────⎟   80⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜  ╱
#             ⎟        2        4⎟          ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜╲╱
#             ⎟   4⋅m_W    8⋅m_W ⎟          ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜───
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜1 -
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎜
#             ⎟                  ⎟          ⎜                      ⎜⎪       ⎝
# otherwise   ⎟                  ⎟          ⎜                      ⎜⎪───────────
#             ⎠                  ⎠          ⎝                      ⎝⎩
# ──────────────────────────────── + ───────────────────────────────────────────
#                                                                             4
#                                                                         3⋅mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                      2
#                             2     ⎞⎞│
#   2⎛ mₕ ⎞                 mₕ      ⎟⎟│
# in ⎜────⎟            for ───── ≤ 1⎟⎟│
#    ⎝2⋅mₜ⎠                    2    ⎟⎟│
#                          4⋅mₜ     ⎟⎟│
#                                   ⎟⎟│
#    ___________    ⎞               ⎟⎟│
#   ╱         2     ⎟               ⎟⎟│
#  ╱      4⋅mₜ      ⎟               ⎟⎟│
# ╱   1 - ─────  + 1⎟               ⎟⎟│
#            2      ⎟               ⎟⎟│
#          mₕ       ⎟               ⎟⎟│
# ──────────────────⎟               ⎟⎟│
#        ___________⎟               ⎟⎟│
#       ╱         2 ⎟               ⎟⎟│
#      ╱      4⋅mₜ  ⎟               ⎟⎟│
#     ╱   1 - ───── ⎟               ⎟⎟│
#    ╱           2  ⎟               ⎟⎟│
#  ╲╱          mₕ   ⎠               ⎟⎟│
# ───────────────────    otherwise  ⎟⎟│
#    4                              ⎠⎠│
# ────────────────────────────────────│
#                                     │
#                                     │
# ──────────────────────────────────────
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# array([0.0006359237438935403, 0.000635919037191914, 0.0006359150616653446,
#        0.0006359116715584218, 0.0006359087560834486,
#        0.0006359062297239969, 0.0006359040255615125,
#        0.0006359020905863486, 0.0006359003823419371,
#        0.0006358988664831775], dtype=object)

# %%
BRhWW(ghWW)
BRhWW(0.3)
# Out:
#                               ⎛
#                               ⎜
#                               ⎜
#                               ⎜                                    ⎛      4
#                               ⎜                                    ⎜60⋅m_W
#                               ⎜                                    ⎜─────── -
#                               ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜    4
#                          2    ⎜  ⎜6⋅m_W    9⋅m_W    3⎟    ⎜m_W ⎟   ⎝  mₕ
# 0.476371951219512⋅g_{hWW} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ───────────
#                               ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                               ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                               ⎜
#                               ⎜
#                               ⎜
#                               ⎜
#                               ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                             3
#                                                                            π ⋅
#
#                  ⎛    ⎛     2    ⎞⎞
#                  ⎜  3 ⎜3⋅m_W     ⎟⎟
#                  ⎜mₕ ⋅⎜────── - 1⎟⎟
#       2    ⎞     ⎜    ⎜   2      ⎟⎟       ⎛     2    ⎞ ⎛      4         2    ⎞
# 24⋅m_W     ⎟     ⎜    ⎝ mₕ       ⎠⎟     2 ⎜  m_W     ⎟ ⎜47⋅m_W    13⋅m_W     ⎟
# ─────── + 3⎟⋅acos⎜────────────────⎟   mₕ ⋅⎜- ──── + 1⎟⋅⎜─────── - ─────── + 2⎟
#     2      ⎟     ⎜          3     ⎟       ⎜    2     ⎟ ⎜    4         2      ⎟
#   mₕ       ⎠     ⎝     2⋅m_W      ⎠       ⎝  mₕ      ⎠ ⎝  mₕ        mₕ       ⎠
# ─────────────────────────────────── - ────────────────────────────────────────
#           ___________                                       2
#          ╱     2                                       2⋅m_W
#         ╱   m_W
#        ╱    ────
#       ╱       2
#      ╱      mₕ
#    ╲╱      4     - 1
# ──────────────────────────────────────────────────────────────────────────────
#    4
# m_W
#
# ⎞
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎟
# ⎠
# ─
# -7.848434449577993e-10

# %%
BRhZZ(ghZZ)
BRhZZ(0.2)
# Out:
#                                        ⎛
#                                        ⎜
#                                        ⎜
#                                        ⎜                                    ⎛
#                                        ⎜                                    ⎜6
#                                        ⎜                                    ⎜─
#                                        ⎜  ⎛     4        2    ⎞    ⎛   2⎞   ⎜
#                                   2    ⎜  ⎜6⋅m_Z    9⋅m_Z    3⎟    ⎜m_Z ⎟   ⎝
# 0.119092987804878⋅\delta_Z⋅g_{HZZ} ⋅mₕ⋅⎜- ⎜────── - ────── + ─⎟⋅log⎜────⎟ + ──
#                                        ⎜  ⎜   4        2     2⎟    ⎜  2 ⎟
#                                        ⎜  ⎝ mₕ       mₕ       ⎠    ⎝mₕ  ⎠
#                                        ⎜
#                                        ⎜
#                                        ⎜
#                                        ⎜
#                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                           ⎛    ⎛     2    ⎞⎞
#                           ⎜  3 ⎜3⋅m_Z     ⎟⎟
#                           ⎜mₕ ⋅⎜────── - 1⎟⎟
#      4         2    ⎞     ⎜    ⎜   2      ⎟⎟       ⎛     2    ⎞ ⎛      4
# 0⋅m_Z    24⋅m_Z     ⎟     ⎜    ⎝ mₕ       ⎠⎟     2 ⎜  m_Z     ⎟ ⎜47⋅m_Z    13⋅
# ────── - ─────── + 3⎟⋅acos⎜────────────────⎟   mₕ ⋅⎜- ──── + 1⎟⋅⎜─────── - ───
#    4         2      ⎟     ⎜          3     ⎟       ⎜    2     ⎟ ⎜    4
#  mₕ        mₕ       ⎠     ⎝     2⋅m_Z      ⎠       ⎝  mₕ      ⎠ ⎝  mₕ        m
# ──────────────────────────────────────────── - ───────────────────────────────
#                    ___________                                       2
#                   ╱     2                                       2⋅m_Z
#                  ╱   m_Z
#                 ╱    ────
#                ╱       2
#               ╱      mₕ
#             ╲╱      4     - 1
# ──────────────────────────────────────────────────────────────────────────────
#   3    4
#  π ⋅m_Z
#
#          ⎞
#          ⎟
#          ⎟
#    2    ⎞⎟
# m_Z     ⎟⎟
# ──── + 2⎟⎟
#  2      ⎟⎟
# ₕ       ⎠⎟
# ─────────⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎟
#          ⎠
# ──────────
# -3.488193088701331e-10

# %%
BRhgg(ghtt,ghbb)
BRhgg(0.1,0.2)
# Out:
#
#                              │                ⎛               ⎛⎧
#                              │                ⎜               ⎜⎪
#                              │                ⎜               ⎜⎪           asi
#                              │                ⎜               ⎜⎪
#                              │                ⎜               ⎜⎪
#                              │                ⎜               ⎜⎪
#                              │                ⎜               ⎜⎪       ⎛ ⎛
#                              │                ⎜               ⎜⎪       ⎜ ⎜
#                              │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜
#                              │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱
#                              │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱
#                              │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱
#                              │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜──────
#                              │                ⎜               ⎜⎪       ⎜
#                              │                ⎜               ⎜⎪       ⎜
#                              │                ⎜               ⎜⎪       ⎜
#                              │                ⎜               ⎜⎪       ⎜     ╱
#                              │                ⎜               ⎜⎪       ⎜    ╱
#                              │                ⎜               ⎜⎪       ⎝  ╲╱
#                              │                ⎜               ⎜⎪──────────────
#                        2   3 │                ⎝               ⎝⎩
# 1.0718368902439⋅\alphaₛ ⋅mₕ ⋅│────────────────────────────────────────────────
#                              │                                               4
#                              │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                              2     ⎞         ⎞                  ⎛
#  2⎛ mₕ ⎞                   mₕ      ⎟         ⎟                  ⎜
# n ⎜────⎟              for ───── ≤ 1⎟         ⎟                  ⎜
#   ⎝2⋅mₜ⎠                      2    ⎟         ⎟                  ⎜
#                           4⋅mₜ     ⎟         ⎟                  ⎜
#                                    ⎟         ⎟                  ⎜
#   ___________    ⎞ ⎞               ⎟         ⎟                  ⎜
#  ╱         2     ⎟ ⎟               ⎟         ⎟                  ⎜
# ╱      4⋅mₜ      ⎟ ⎟               ⎟      2  ⎟                  ⎜   2      ⎛
#    1 - ─────  + 1⎟ ⎟               ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ m
#           2      ⎟ ⎟               ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜──
#         mₕ       ⎠ ⎟               ⎟        2⎟                  ⎜    2     ⎜
# ───────────────────⎟               ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅
#   ___________      ⎟               ⎟         ⎟                  ⎜
#  ╱         2       ⎟               ⎟         ⎟                  ⎜
# ╱      4⋅mₜ        ⎟               ⎟         ⎟                  ⎜
#    1 - ─────  - 1  ⎟               ⎟         ⎟                  ⎜
#           2        ⎟               ⎟         ⎟                  ⎜
#         mₕ         ⎠               ⎟         ⎟                  ⎜
# ────────────────────    otherwise  ⎟         ⎟                  ⎜
#   4                                ⎠         ⎠                  ⎝
# ────────────────────────────────────────────── - ─────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                 3
#                                π
#
#                                                                2
#          ⎛⎧                                           2     ⎞⎞│
#          ⎜⎪               2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#          ⎜⎪           asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#          ⎜⎪                ⎝2⋅mₜ⎠                      2    ⎟⎟│
#          ⎜⎪                                        4⋅mₜ     ⎟⎟│
#          ⎜⎪                                                 ⎟⎟│
#          ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#          ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#  2     ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
# ₕ      ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
# ─── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#   2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# mₜ     ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟               ⎟⎟│
#          ⎜⎪       ⎜        ___________      ⎟               ⎟⎟│
#          ⎜⎪       ⎜       ╱         2       ⎟               ⎟⎟│
#          ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#          ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#          ⎜⎪       ⎜    ╱           2        ⎟               ⎟⎟│
#          ⎜⎪       ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
#          ⎜⎪──────────────────────────────────    otherwise  ⎟⎟│
#          ⎝⎩                4                                ⎠⎠│
# ──────────────────────────────────────────────────────────────│
#                  4                                            │
#                mₕ                                             │
# ────────────────────────────────────────────────────────────────
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# 0.001343136386395579

# %%
Rbotbot(ghtt,ghbb)
Rbotbot(0.1,0.2)
# Out:
#
#                   │                ⎛               ⎛⎧
#                   │                ⎜               ⎜⎪               2⎛ mₕ ⎞
#                   │                ⎜               ⎜⎪           asin ⎜────⎟
#                   │                ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#                   │                ⎜               ⎜⎪
#                   │                ⎜               ⎜⎪
#                   │                ⎜               ⎜⎪       ⎛ ⎛      _________
#                   │                ⎜               ⎜⎪       ⎜ ⎜     ╱
#                   │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ
#                   │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ────
#                   │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2
#                   │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#                   │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜─────────────────
#                   │                ⎜               ⎜⎪       ⎜        _________
#                   │                ⎜               ⎜⎪       ⎜       ╱
#                   │                ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#                   │                ⎜               ⎜⎪       ⎜     ╱   1 - ────
#                   │                ⎜               ⎜⎪       ⎜    ╱           2
#                   │                ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#                   │                ⎜               ⎜⎪─────────────────────────
#            2    2 │                ⎝               ⎝⎩                4
# 4.0⋅g_{hbb} ⋅m_W ⋅│───────────────────────────────────────────────────────────
#                   │                                               4
#                   │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                     │         ⎛               ⎛⎧
#                     │         ⎜               ⎜⎪               2⎛ mₕ ⎞
#                     │         ⎜               ⎜⎪           asin ⎜────⎟
#                     │         ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#                     │         ⎜               ⎜⎪
#                     │         ⎜               ⎜⎪
#                     │         ⎜               ⎜⎪       ⎛ ⎛      ___________
#                     │         ⎜               ⎜⎪       ⎜ ⎜     ╱         2
#                     │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ
#                     │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  +
#                     │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2
#                     │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#                     │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜──────────────────────
#                     │         ⎜               ⎜⎪       ⎜        ___________
#                     │         ⎜               ⎜⎪       ⎜       ╱         2
#                     │         ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#                     │         ⎜               ⎜⎪       ⎜     ╱   1 - ─────  -
#                     │         ⎜               ⎜⎪       ⎜    ╱           2
#                     │         ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#                     │         ⎜               ⎜⎪──────────────────────────────
#              2    2 │         ⎝               ⎝⎩                4
#             g ⋅m_b ⋅│─────────────────────────────────────────────────────────
#                     │                                              4
#                     │                                        m_W⋅mₕ
#
#
#                   2     ⎞         ⎞                  ⎛                      ⎛⎧
#                 mₕ      ⎟         ⎟                  ⎜                      ⎜⎪
#            for ───── ≤ 1⎟         ⎟                  ⎜                      ⎜⎪
#                    2    ⎟         ⎟                  ⎜                      ⎜⎪
#                4⋅mₜ     ⎟         ⎟                  ⎜                      ⎜⎪
#                         ⎟         ⎟                  ⎜                      ⎜⎪
# __    ⎞ ⎞               ⎟         ⎟                  ⎜                      ⎜⎪
# 2     ⎟ ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#       ⎟ ⎟               ⎟      2  ⎟                  ⎜   2      ⎛   2     ⎞ ⎜⎪
# ─  + 1⎟ ⎟               ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
#       ⎟ ⎟               ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#       ⎠ ⎟               ⎟        2⎟                  ⎜    2     ⎜    2    ⎟ ⎜⎪
# ────────⎟               ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪
# __      ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
# 2       ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#         ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
# ─  - 1  ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#         ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#         ⎠               ⎟         ⎟                  ⎜                      ⎜⎪
# ─────────    otherwise  ⎟         ⎟                  ⎜                      ⎜⎪
#                         ⎠         ⎠                  ⎝                      ⎝⎩
# ─────────────────────────────────── - ────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#              2     ⎞         ⎞           ⎛                      ⎛⎧
#            mₕ      ⎟         ⎟           ⎜                      ⎜⎪
#       for ───── ≤ 1⎟         ⎟           ⎜                      ⎜⎪           a
#               2    ⎟         ⎟           ⎜                      ⎜⎪
#           4⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#                    ⎟         ⎟           ⎜                      ⎜⎪
#  ⎞ ⎞               ⎟         ⎟           ⎜                      ⎜⎪       ⎛ ⎛
#  ⎟ ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜ ⎜
#  ⎟ ⎟               ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜
# 1⎟ ⎟               ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜
#  ⎟ ⎟               ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜
#  ⎠ ⎟               ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱
# ───⎟               ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜────
#    ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#    ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#    ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
# 1  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#    ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#    ⎠               ⎟         ⎟           ⎜                      ⎜⎪       ⎝  ╲╱
# ────    otherwise  ⎟         ⎟           ⎜                      ⎜⎪────────────
#                    ⎠         ⎠           ⎝                      ⎝⎩
# ────────────────────────────── - ─────────────────────────────────────────────
#                                                                              4
#                                                                        m_W⋅mₕ
#
#                                                     2
#                                            2     ⎞⎞│
#                2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#            asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#                 ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                         4⋅mₜ     ⎟⎟│
#                                                  ⎟⎟│
#        ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#        ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#        ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#        ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#        ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#  2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# π ⋅log ⎜─────────────────────────⎟               ⎟⎟│
#        ⎜        ___________      ⎟               ⎟⎟│
#        ⎜       ╱         2       ⎟               ⎟⎟│
#        ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#        ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#        ⎜    ╱           2        ⎟               ⎟⎟│
#        ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ──────────────────────────────────    otherwise  ⎟⎟│
#                 4                                ⎠⎠│
# ───────────────────────────────────────────────────│
#       4                                            │
#     mₕ                                             │
# ─────────────────────────────────────────────────────
#                                         2
#                                2     ⎞⎞│
#    2⎛ mₕ ⎞                   mₕ      ⎟⎟│
# sin ⎜────⎟              for ───── ≤ 1⎟⎟│
#     ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                             4⋅mₜ     ⎟⎟│
#                                      ⎟⎟│
#     ___________    ⎞ ⎞               ⎟⎟│
#    ╱         2     ⎟ ⎟               ⎟⎟│
#   ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#  ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
# ╱           2      ⎟ ⎟               ⎟⎟│
#           mₕ       ⎠ ⎟               ⎟⎟│
# ─────────────────────⎟               ⎟⎟│
#     ___________      ⎟               ⎟⎟│
#    ╱         2       ⎟               ⎟⎟│
#   ╱      4⋅mₜ        ⎟               ⎟⎟│
#  ╱   1 - ─────  - 1  ⎟               ⎟⎟│
# ╱           2        ⎟               ⎟⎟│
#           mₕ         ⎠               ⎟⎟│
# ──────────────────────    otherwise  ⎟⎟│
#     4                                ⎠⎠│
# ───────────────────────────────────────│
#                                        │
#                                        │
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# 7.140222352069548

# %%
ghtautau = sp.symbols(r'g_{h\tau\tau}',real=True)
Rtata(ghtt,ghbb,ghtautau)
Rtata(0.1,0.2,0.01)
# Out:
#
#                         │                ⎛               ⎛⎧
#                         │                ⎜               ⎜⎪               2⎛ m
#                         │                ⎜               ⎜⎪           asin ⎜──
#                         │                ⎜               ⎜⎪                ⎝2⋅
#                         │                ⎜               ⎜⎪
#                         │                ⎜               ⎜⎪
#                         │                ⎜               ⎜⎪       ⎛ ⎛      ___
#                         │                ⎜               ⎜⎪       ⎜ ⎜     ╱
#                         │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱
#                         │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1
#                         │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱
#                         │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱
#                         │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜───────────
#                         │                ⎜               ⎜⎪       ⎜        ___
#                         │                ⎜               ⎜⎪       ⎜       ╱
#                         │                ⎜               ⎜⎪       ⎜      ╱
#                         │                ⎜               ⎜⎪       ⎜     ╱   1
#                         │                ⎜               ⎜⎪       ⎜    ╱
#                         │                ⎜               ⎜⎪       ⎝  ╲╱
#                         │                ⎜               ⎜⎪───────────────────
#                  2    2 │                ⎝               ⎝⎩                4
# 4.0⋅g_{h\tau\tau} ⋅m_W ⋅│─────────────────────────────────────────────────────
#                         │                                               4
#                         │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                           │         ⎛               ⎛⎧
#                           │         ⎜               ⎜⎪               2⎛ mₕ ⎞
#                           │         ⎜               ⎜⎪           asin ⎜────⎟
#                           │         ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#                           │         ⎜               ⎜⎪
#                           │         ⎜               ⎜⎪
#                           │         ⎜               ⎜⎪       ⎛ ⎛      ________
#                           │         ⎜               ⎜⎪       ⎜ ⎜     ╱
#                           │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅m
#                           │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ───
#                           │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱
#                           │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#                           │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜────────────────
#                           │         ⎜               ⎜⎪       ⎜        ________
#                           │         ⎜               ⎜⎪       ⎜       ╱
#                           │         ⎜               ⎜⎪       ⎜      ╱      4⋅m
#                           │         ⎜               ⎜⎪       ⎜     ╱   1 - ───
#                           │         ⎜               ⎜⎪       ⎜    ╱
#                           │         ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#                           │         ⎜               ⎜⎪────────────────────────
#               2         2 │         ⎝               ⎝⎩                4
#              g ⋅m_{\tau} ⋅│───────────────────────────────────────────────────
#                           │                                              4
#                           │                                        m_W⋅mₕ
#
#
#                         2     ⎞         ⎞                  ⎛
# ₕ ⎞                   mₕ      ⎟         ⎟                  ⎜
# ──⎟              for ───── ≤ 1⎟         ⎟                  ⎜
# mₜ⎠                      2    ⎟         ⎟                  ⎜
#                      4⋅mₜ     ⎟         ⎟                  ⎜
#                               ⎟         ⎟                  ⎜
# ________    ⎞ ⎞               ⎟         ⎟                  ⎜
#       2     ⎟ ⎟               ⎟         ⎟                  ⎜
#   4⋅mₜ      ⎟ ⎟               ⎟      2  ⎟                  ⎜   2      ⎛   2
# - ─────  + 1⎟ ⎟               ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ
#      2      ⎟ ⎟               ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── -
#    mₕ       ⎠ ⎟               ⎟        2⎟                  ⎜    2     ⎜    2
# ──────────────⎟               ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ
# ________      ⎟               ⎟         ⎟                  ⎜
#       2       ⎟               ⎟         ⎟                  ⎜
#   4⋅mₜ        ⎟               ⎟         ⎟                  ⎜
# - ─────  - 1  ⎟               ⎟         ⎟                  ⎜
#      2        ⎟               ⎟         ⎟                  ⎜
#    mₕ         ⎠               ⎟         ⎟                  ⎜
# ───────────────    otherwise  ⎟         ⎟                  ⎜
#                               ⎠         ⎠                  ⎝
# ───────────────────────────────────────── - ──────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#                    2     ⎞         ⎞           ⎛                      ⎛⎧
#                  mₕ      ⎟         ⎟           ⎜                      ⎜⎪
#             for ───── ≤ 1⎟         ⎟           ⎜                      ⎜⎪
#                     2    ⎟         ⎟           ⎜                      ⎜⎪
#                 4⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#                          ⎟         ⎟           ⎜                      ⎜⎪
# ___    ⎞ ⎞               ⎟         ⎟           ⎜                      ⎜⎪
#  2     ⎟ ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# ₜ      ⎟ ⎟               ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪
# ──  + 1⎟ ⎟               ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
# 2      ⎟ ⎟               ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#        ⎠ ⎟               ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2
# ─────────⎟               ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log
# ___      ⎟               ⎟         ⎟           ⎜                      ⎜⎪
#  2       ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# ₜ        ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# ──  - 1  ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# 2        ⎟               ⎟         ⎟           ⎜                      ⎜⎪
#          ⎠               ⎟         ⎟           ⎜                      ⎜⎪
# ──────────    otherwise  ⎟         ⎟           ⎜                      ⎜⎪──────
#                          ⎠         ⎠           ⎝                      ⎝⎩
# ──────────────────────────────────── - ───────────────────────────────────────
#
#                                                                              m
#
#                                                           2
#     ⎛⎧                                           2     ⎞⎞│
#     ⎜⎪               2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#     ⎜⎪           asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#     ⎜⎪                ⎝2⋅mₜ⎠                      2    ⎟⎟│
#     ⎜⎪                                        4⋅mₜ     ⎟⎟│
#     ⎜⎪                                                 ⎟⎟│
#     ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#     ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#   ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#  1⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#   ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
#   ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟               ⎟⎟│
#     ⎜⎪       ⎜        ___________      ⎟               ⎟⎟│
#     ⎜⎪       ⎜       ╱         2       ⎟               ⎟⎟│
#     ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#     ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#     ⎜⎪       ⎜    ╱           2        ⎟               ⎟⎟│
#     ⎜⎪       ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
#     ⎜⎪──────────────────────────────────    otherwise  ⎟⎟│
#     ⎝⎩                4                                ⎠⎠│
# ─────────────────────────────────────────────────────────│
#             4                                            │
#           mₕ                                             │
# ───────────────────────────────────────────────────────────
#                                               2
#                                      2     ⎞⎞│
#          2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#      asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#           ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                   4⋅mₜ     ⎟⎟│
#                                            ⎟⎟│
#  ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#  ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#  ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#  ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#  ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
# 2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
#  ⎜─────────────────────────⎟               ⎟⎟│
#  ⎜        ___________      ⎟               ⎟⎟│
#  ⎜       ╱         2       ⎟               ⎟⎟│
#  ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#  ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#  ⎜    ╱           2        ⎟               ⎟⎟│
#  ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ────────────────────────────    otherwise  ⎟⎟│
#           4                                ⎠⎠│
# ─────────────────────────────────────────────│
#      4                                       │
# _W⋅mₕ                                        │
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# 0.0987865655564779

# %%
RWW(ghtt,ghbb,ghWW)
RWW(0.1,0.2,0.01)
# Out:
#
#              │                ⎛               ⎛⎧
#              │                ⎜               ⎜⎪               2⎛ mₕ ⎞
#              │                ⎜               ⎜⎪           asin ⎜────⎟
#              │                ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#              │                ⎜               ⎜⎪
#              │                ⎜               ⎜⎪
#              │                ⎜               ⎜⎪       ⎛ ⎛      ___________
#              │                ⎜               ⎜⎪       ⎜ ⎜     ╱         2
#              │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ
#              │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  +
#              │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2
#              │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#              │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜──────────────────────
#              │                ⎜               ⎜⎪       ⎜        ___________
#              │                ⎜               ⎜⎪       ⎜       ╱         2
#              │                ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#              │                ⎜               ⎜⎪       ⎜     ╱   1 - ─────  -
#              │                ⎜               ⎜⎪       ⎜    ╱           2
#              │                ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#              │                ⎜               ⎜⎪──────────────────────────────
#            2 │                ⎝               ⎝⎩                4
# 1.0⋅g_{hWW} ⋅│────────────────────────────────────────────────────────────────
#              │                                               4
#              │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                   │         ⎛               ⎛⎧
#                   │         ⎜               ⎜⎪               2⎛ mₕ ⎞
#                   │         ⎜               ⎜⎪           asin ⎜────⎟
#                   │         ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪       ⎛ ⎛      ___________    ⎞
#                   │         ⎜               ⎜⎪       ⎜ ⎜     ╱         2     ⎟
#                   │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟
#                   │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟
#                   │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟
#                   │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠
#                   │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜────────────────────────
#                   │         ⎜               ⎜⎪       ⎜        ___________
#                   │         ⎜               ⎜⎪       ⎜       ╱         2
#                   │         ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#                   │         ⎜               ⎜⎪       ⎜     ╱   1 - ─────  - 1
#                   │         ⎜               ⎜⎪       ⎜    ╱           2
#                   │         ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#                   │         ⎜               ⎜⎪────────────────────────────────
#            2    2 │         ⎝               ⎝⎩                4
#         g_w ⋅m_W ⋅│───────────────────────────────────────────────────────────
#                   │                                              4
#                   │                                        m_W⋅mₕ
#
#
#              2     ⎞         ⎞                  ⎛                      ⎛⎧
#            mₕ      ⎟         ⎟                  ⎜                      ⎜⎪
#       for ───── ≤ 1⎟         ⎟                  ⎜                      ⎜⎪
#               2    ⎟         ⎟                  ⎜                      ⎜⎪
#           4⋅mₜ     ⎟         ⎟                  ⎜                      ⎜⎪
#                    ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎞ ⎞               ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎟ ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎟ ⎟               ⎟      2  ⎟                  ⎜   2      ⎛   2     ⎞ ⎜⎪
# 1⎟ ⎟               ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
#  ⎟ ⎟               ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#  ⎠ ⎟               ⎟        2⎟                  ⎜    2     ⎜    2    ⎟ ⎜⎪ 2
# ───⎟               ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅lo
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
# 1  ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎠               ⎟         ⎟                  ⎜                      ⎜⎪
# ────    otherwise  ⎟         ⎟                  ⎜                      ⎜⎪─────
#                    ⎠         ⎠                  ⎝                      ⎝⎩
# ────────────────────────────── - ─────────────────────────────────────────────
#
#                                                                              m
# ──────────────────────────────────────────────────────────────────────────────
#
#            2     ⎞         ⎞           ⎛                      ⎛⎧
#          mₕ      ⎟         ⎟           ⎜                      ⎜⎪
#     for ───── ≤ 1⎟         ⎟           ⎜                      ⎜⎪           asi
#             2    ⎟         ⎟           ⎜                      ⎜⎪
#         4⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#                  ⎟         ⎟           ⎜                      ⎜⎪
#  ⎞               ⎟         ⎟           ⎜                      ⎜⎪       ⎛ ⎛
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜ ⎜
#  ⎟               ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜
#  ⎟               ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱
#  ⎟               ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱
#  ⎟               ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱
# ─⎟               ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜──────
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜     ╱
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜    ╱
#  ⎠               ⎟         ⎟           ⎜                      ⎜⎪       ⎝  ╲╱
# ──    otherwise  ⎟         ⎟           ⎜                      ⎜⎪──────────────
#                  ⎠         ⎠           ⎝                      ⎝⎩
# ──────────────────────────── - ───────────────────────────────────────────────
#                                                                            4
#                                                                      m_W⋅mₕ
#
#                                                2
#                                       2     ⎞⎞│
#           2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#       asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#            ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                    4⋅mₜ     ⎟⎟│
#                                             ⎟⎟│
#   ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#   ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#   ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#   ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#   ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#  2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# g ⎜─────────────────────────⎟               ⎟⎟│
#   ⎜        ___________      ⎟               ⎟⎟│
#   ⎜       ╱         2       ⎟               ⎟⎟│
#   ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#   ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#   ⎜    ╱           2        ⎟               ⎟⎟│
#   ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ─────────────────────────────    otherwise  ⎟⎟│
#            4                                ⎠⎠│
# ──────────────────────────────────────────────│
#  4                                            │
# ₕ                                             │
# ────────────────────────────────────────────────
#                                       2
#                              2     ⎞⎞│
#  2⎛ mₕ ⎞                   mₕ      ⎟⎟│
# n ⎜────⎟              for ───── ≤ 1⎟⎟│
#   ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                           4⋅mₜ     ⎟⎟│
#                                    ⎟⎟│
#   ___________    ⎞ ⎞               ⎟⎟│
#  ╱         2     ⎟ ⎟               ⎟⎟│
# ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#    1 - ─────  + 1⎟ ⎟               ⎟⎟│
#           2      ⎟ ⎟               ⎟⎟│
#         mₕ       ⎠ ⎟               ⎟⎟│
# ───────────────────⎟               ⎟⎟│
#   ___________      ⎟               ⎟⎟│
#  ╱         2       ⎟               ⎟⎟│
# ╱      4⋅mₜ        ⎟               ⎟⎟│
#    1 - ─────  - 1  ⎟               ⎟⎟│
#           2        ⎟               ⎟⎟│
#         mₕ         ⎠               ⎟⎟│
# ────────────────────    otherwise  ⎟⎟│
#   4                                ⎠⎠│
# ─────────────────────────────────────│
#                                      │
#                                      │
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# 1.940011578331498e-09

# %%
RZZ(ghtt,ghbb,ghZZ)
RZZ(0.1,0.2,0.01)
# Out:
#
#              │                ⎛               ⎛⎧
#              │                ⎜               ⎜⎪               2⎛ mₕ ⎞
#              │                ⎜               ⎜⎪           asin ⎜────⎟
#              │                ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#              │                ⎜               ⎜⎪
#              │                ⎜               ⎜⎪
#              │                ⎜               ⎜⎪       ⎛ ⎛      ___________
#              │                ⎜               ⎜⎪       ⎜ ⎜     ╱         2
#              │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ
#              │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  +
#              │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2
#              │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#              │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜──────────────────────
#              │                ⎜               ⎜⎪       ⎜        ___________
#              │                ⎜               ⎜⎪       ⎜       ╱         2
#              │                ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#              │                ⎜               ⎜⎪       ⎜     ╱   1 - ─────  -
#              │                ⎜               ⎜⎪       ⎜    ╱           2
#              │                ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#              │                ⎜               ⎜⎪──────────────────────────────
#            2 │                ⎝               ⎝⎩                4
# 1.0⋅g_{HZZ} ⋅│────────────────────────────────────────────────────────────────
#              │                                               4
#              │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                   │         ⎛               ⎛⎧
#                   │         ⎜               ⎜⎪               2⎛ mₕ ⎞
#                   │         ⎜               ⎜⎪           asin ⎜────⎟
#                   │         ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪
#                   │         ⎜               ⎜⎪       ⎛ ⎛      ___________    ⎞
#                   │         ⎜               ⎜⎪       ⎜ ⎜     ╱         2     ⎟
#                   │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟
#                   │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟
#                   │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟
#                   │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠
#                   │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜────────────────────────
#                   │         ⎜               ⎜⎪       ⎜        ___________
#                   │         ⎜               ⎜⎪       ⎜       ╱         2
#                   │         ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ
#                   │         ⎜               ⎜⎪       ⎜     ╱   1 - ─────  - 1
#                   │         ⎜               ⎜⎪       ⎜    ╱           2
#                   │         ⎜               ⎜⎪       ⎝  ╲╱          mₕ
#                   │         ⎜               ⎜⎪────────────────────────────────
#            2    2 │         ⎝               ⎝⎩                4
#         g_z ⋅m_Z ⋅│───────────────────────────────────────────────────────────
#                   │                                              4
#                   │                                        m_W⋅mₕ
#
#
#              2     ⎞         ⎞                  ⎛                      ⎛⎧
#            mₕ      ⎟         ⎟                  ⎜                      ⎜⎪
#       for ───── ≤ 1⎟         ⎟                  ⎜                      ⎜⎪
#               2    ⎟         ⎟                  ⎜                      ⎜⎪
#           4⋅mₜ     ⎟         ⎟                  ⎜                      ⎜⎪
#                    ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎞ ⎞               ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎟ ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#  ⎟ ⎟               ⎟      2  ⎟                  ⎜   2      ⎛   2     ⎞ ⎜⎪
# 1⎟ ⎟               ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
#  ⎟ ⎟               ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#  ⎠ ⎟               ⎟        2⎟                  ⎜    2     ⎜    2    ⎟ ⎜⎪ 2
# ───⎟               ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅lo
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
# 1  ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎟               ⎟         ⎟                  ⎜                      ⎜⎪
#    ⎠               ⎟         ⎟                  ⎜                      ⎜⎪
# ────    otherwise  ⎟         ⎟                  ⎜                      ⎜⎪─────
#                    ⎠         ⎠                  ⎝                      ⎝⎩
# ────────────────────────────── - ─────────────────────────────────────────────
#
#                                                                              m
# ──────────────────────────────────────────────────────────────────────────────
#
#            2     ⎞         ⎞           ⎛                      ⎛⎧
#          mₕ      ⎟         ⎟           ⎜                      ⎜⎪
#     for ───── ≤ 1⎟         ⎟           ⎜                      ⎜⎪           asi
#             2    ⎟         ⎟           ⎜                      ⎜⎪
#         4⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#                  ⎟         ⎟           ⎜                      ⎜⎪
#  ⎞               ⎟         ⎟           ⎜                      ⎜⎪       ⎛ ⎛
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜ ⎜
#  ⎟               ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜
#  ⎟               ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱
#  ⎟               ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱
#  ⎟               ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱
# ─⎟               ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜──────
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜     ╱
#  ⎟               ⎟         ⎟           ⎜                      ⎜⎪       ⎜    ╱
#  ⎠               ⎟         ⎟           ⎜                      ⎜⎪       ⎝  ╲╱
# ──    otherwise  ⎟         ⎟           ⎜                      ⎜⎪──────────────
#                  ⎠         ⎠           ⎝                      ⎝⎩
# ──────────────────────────── - ───────────────────────────────────────────────
#                                                                            4
#                                                                      m_W⋅mₕ
#
#                                                2
#                                       2     ⎞⎞│
#           2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#       asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#            ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                    4⋅mₜ     ⎟⎟│
#                                             ⎟⎟│
#   ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#   ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#   ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#   ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#   ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#  2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# g ⎜─────────────────────────⎟               ⎟⎟│
#   ⎜        ___________      ⎟               ⎟⎟│
#   ⎜       ╱         2       ⎟               ⎟⎟│
#   ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#   ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#   ⎜    ╱           2        ⎟               ⎟⎟│
#   ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ─────────────────────────────    otherwise  ⎟⎟│
#            4                                ⎠⎠│
# ──────────────────────────────────────────────│
#  4                                            │
# ₕ                                             │
# ────────────────────────────────────────────────
#                                       2
#                              2     ⎞⎞│
#  2⎛ mₕ ⎞                   mₕ      ⎟⎟│
# n ⎜────⎟              for ───── ≤ 1⎟⎟│
#   ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                           4⋅mₜ     ⎟⎟│
#                                    ⎟⎟│
#   ___________    ⎞ ⎞               ⎟⎟│
#  ╱         2     ⎟ ⎟               ⎟⎟│
# ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#    1 - ─────  + 1⎟ ⎟               ⎟⎟│
#           2      ⎟ ⎟               ⎟⎟│
#         mₕ       ⎠ ⎟               ⎟⎟│
# ───────────────────⎟               ⎟⎟│
#   ___________      ⎟               ⎟⎟│
#  ╱         2       ⎟               ⎟⎟│
# ╱      4⋅mₜ        ⎟               ⎟⎟│
#    1 - ─────  - 1  ⎟               ⎟⎟│
#           2        ⎟               ⎟⎟│
#         mₕ         ⎠               ⎟⎟│
# ────────────────────    otherwise  ⎟⎟│
#   4                                ⎠⎠│
# ─────────────────────────────────────│
#                                      │
#                                      │
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# 1.1712013790896896e-09

# %%
Rgaga(ghtt,ghbb,ghWW,gCH,mCH).simplify()
Rgaga(0.1,0.2,0.3,0.001,200)
# Out:
#
#     │                ⎛               ⎛⎧
#     │                ⎜               ⎜⎪               2⎛ mₕ ⎞
#     │                ⎜               ⎜⎪           asin ⎜────⎟              for
#     │                ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#     │                ⎜               ⎜⎪
#     │                ⎜               ⎜⎪
#     │                ⎜               ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞
#     │                ⎜               ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟
#     │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟
#     │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟
#     │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟ ⎟
#     │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟
#     │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟
#     │                ⎜               ⎜⎪       ⎜        ___________      ⎟
#     │                ⎜               ⎜⎪       ⎜       ╱         2       ⎟
#     │                ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟
#     │                ⎜               ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟
#     │                ⎜               ⎜⎪       ⎜    ╱           2        ⎟
#     │                ⎜               ⎜⎪       ⎝  ╲╱          mₕ         ⎠
#     │                ⎜               ⎜⎪──────────────────────────────────    o
#     │                ⎝               ⎝⎩                4
# 1.0⋅│─────────────────────────────────────────────────────────────────────────
#     │                                               4
#     │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │  16
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │
#                                                                          │- ──
#                                                                          │
#                                                                          │
#
#
#     2     ⎞         ⎞                  ⎛                      ⎛⎧
#   mₕ      ⎟         ⎟                  ⎜                      ⎜⎪
#  ───── ≤ 1⎟         ⎟                  ⎜                      ⎜⎪           asi
#      2    ⎟         ⎟                  ⎜                      ⎜⎪
#  4⋅mₜ     ⎟         ⎟                  ⎜                      ⎜⎪
#           ⎟         ⎟                  ⎜                      ⎜⎪
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎛ ⎛
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜ ⎜
#           ⎟      2  ⎟                  ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜
#           ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱
#           ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱
#           ⎟        2⎟                  ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱
#           ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜──────
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜     ╱
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜    ╱
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎝  ╲╱
# therwise  ⎟         ⎟                  ⎜                      ⎜⎪──────────────
#           ⎠         ⎠                  ⎝                      ⎝⎩
# ───────────────────── - ──────────────────────────────────────────────────────
#                                                                       4
#                                                                     mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#           ⎛              ⎛⎧                                          2      ⎞
#           ⎜              ⎜⎪              2⎛  mₕ ⎞                  mₕ       ⎟
#           ⎜              ⎜⎪          asin ⎜─────⎟             for ────── ≤ 1⎟
#           ⎜              ⎜⎪               ⎝2⋅m_W⎠                      2    ⎟
#           ⎜              ⎜⎪                                       4⋅m_W     ⎟
#           ⎜              ⎜⎪                                                 ⎟
#           ⎜              ⎜⎪       ⎛      ______________    ⎞                ⎟
#           ⎜              ⎜⎪       ⎜     ╱        2         ⎟                ⎟
#           ⎜⎛         2 ⎞ ⎜⎪       ⎜    ╱    4⋅m_W          ⎟                ⎟
#         4 ⎜⎜     3⋅mₕ  ⎟ ⎜⎪       ⎜   ╱   - ────── + 1  + 1⎟                ⎟
# ⋅g_w⋅m_W ⋅⎜⎜-3 + ──────⎟⋅⎜⎨       ⎜  ╱         2           ⎟                ⎟
#           ⎜⎜          2⎟ ⎜⎪ 2    2⎜╲╱        mₕ            ⎟                ⎟
#           ⎜⎝     2⋅m_W ⎠ ⎜⎪π ⋅log ⎜────────────────────────⎟                ⎟
#           ⎜              ⎜⎪       ⎜          ______________⎟                ⎟
#           ⎜              ⎜⎪       ⎜         ╱        2     ⎟                ⎟
#           ⎜              ⎜⎪       ⎜        ╱    4⋅m_W      ⎟                ⎟
#           ⎜              ⎜⎪       ⎜1 -    ╱   - ────── + 1 ⎟                ⎟
#           ⎜              ⎜⎪       ⎜      ╱         2       ⎟                ⎟
#           ⎜              ⎜⎪       ⎝    ╲╱        mₕ        ⎠                ⎟
#           ⎜              ⎜⎪─────────────────────────────────    otherwise   ⎟
#           ⎝              ⎝⎩                4                                ⎠
# ──────────────────────────────────────────────────────────────────────────────
#                                                4
#                                              mₕ
#
#                                       2
#                              2     ⎞⎞│  │                                    ⎛
#  2⎛ mₕ ⎞                   mₕ      ⎟⎟│  │                                    ⎜
# n ⎜────⎟              for ───── ≤ 1⎟⎟│  │                                    ⎜
#   ⎝2⋅mₜ⎠                      2    ⎟⎟│  │                                    ⎜
#                           4⋅mₜ     ⎟⎟│  │                                    ⎜
#                                    ⎟⎟│  │                                    ⎜
#   ___________    ⎞ ⎞               ⎟⎟│  │                                    ⎜
#  ╱         2     ⎟ ⎟               ⎟⎟│  │                                    ⎜
# ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│  │                                    ⎜
#    1 - ─────  + 1⎟ ⎟               ⎟⎟│  │                                  2 ⎜
#           2      ⎟ ⎟               ⎟⎟│  │  16⋅g_{H__{\pm}}⋅m_W⋅m_{H__{\pm}} ⋅⎜
#         mₕ       ⎠ ⎟               ⎟⎟│  │                                    ⎜
# ───────────────────⎟               ⎟⎟│  │                                    ⎜
#   ___________      ⎟               ⎟⎟│  │                                    ⎜
#  ╱         2       ⎟               ⎟⎟│  │                                    ⎜
# ╱      4⋅mₜ        ⎟               ⎟⎟│  │                                    ⎜
#    1 - ─────  - 1  ⎟               ⎟⎟│  │                                    ⎜
#           2        ⎟               ⎟⎟│  │                                    ⎜
#         mₕ         ⎠               ⎟⎟│  │                                    ⎜
# ────────────────────    otherwise  ⎟⎟│  │                                    ⎜
#   4                                ⎠⎠│  │                                    ⎝
# ─────────────────────────────────────│ ⋅│- ───────────────────────────────────
#                                      │  │
#                                      │  │
# ──────────────────────────────────────────────────────────────────────────────
#
#                  ⎞          ⎛                      ⎛⎧
#                  ⎟          ⎜                      ⎜⎪               2⎛ mₕ ⎞
#                  ⎟          ⎜                      ⎜⎪           asin ⎜────⎟
#                  ⎟          ⎜                      ⎜⎪                ⎝2⋅mₜ⎠
#                  ⎟          ⎜                      ⎜⎪
#                  ⎟          ⎜                      ⎜⎪
#                  ⎟          ⎜                      ⎜⎪       ⎛ ⎛      _________
#                  ⎟          ⎜                      ⎜⎪       ⎜ ⎜     ╱
#       2       4  ⎟          ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ
#   3⋅mₕ      mₕ   ⎟        4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ────
# + ────── + ──────⎟   80⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱           2
#        2        4⎟          ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ
#   4⋅m_W    8⋅m_W ⎟          ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜─────────────────
#                  ⎟          ⎜                      ⎜⎪       ⎜        _________
#                  ⎟          ⎜                      ⎜⎪       ⎜       ╱
#                  ⎟          ⎜                      ⎜⎪       ⎜      ╱      4⋅mₜ
#                  ⎟          ⎜                      ⎜⎪       ⎜     ╱   1 - ────
#                  ⎟          ⎜                      ⎜⎪       ⎜    ╱           2
#                  ⎟          ⎜                      ⎜⎪       ⎝  ╲╱          mₕ
#                  ⎟          ⎜                      ⎜⎪─────────────────────────
#                  ⎠          ⎝                      ⎝⎩                4
# ────────────────── + ─────────────────────────────────────────────────────────
#                                                                 4
#                                                             3⋅mₕ
#
#
#                   ⎛⎧                                                      2
#                   ⎜⎪             2⎛      mₕ      ⎞                      mₕ
#                   ⎜⎪         asin ⎜──────────────⎟            for ────────────
#                   ⎜⎪              ⎝2⋅m_{H__{\pm}}⎠
#                   ⎜⎪                                              4⋅m_{H__{\pm
#                   ⎜⎪
#                   ⎜⎪       ⎛      _____________________    ⎞
#                   ⎜⎪       ⎜     ╱                   2     ⎟
#         2         ⎜⎪       ⎜    ╱      4⋅m_{H__{\pm}}      ⎟
#       mₕ          ⎜⎪       ⎜   ╱   1 - ───────────────  + 1⎟
# ─────────────── - ⎜⎨       ⎜  ╱                2           ⎟
#               2   ⎜⎪ 2    2⎜╲╱               mₕ            ⎟
# 4⋅m_{H__{\pm}}    ⎜⎪π ⋅log ⎜───────────────────────────────⎟
#                   ⎜⎪       ⎜          _____________________⎟
#                   ⎜⎪       ⎜         ╱                   2 ⎟
#                   ⎜⎪       ⎜        ╱      4⋅m_{H__{\pm}}  ⎟
#                   ⎜⎪       ⎜1 -    ╱   1 - ─────────────── ⎟
#                   ⎜⎪       ⎜      ╱                2       ⎟
#                   ⎜⎪       ⎝    ╲╱               mₕ        ⎠
#                   ⎜⎪────────────────────────────────────────         otherwise
#                   ⎝⎩                   4
# ──────────────────────────────────────────────────────────────────────────────
#                           4
#                         mₕ
# ──────────────────────────────────────────────────────────────────────────────
#                            2
#                   2     ⎞⎞│  │         ⎛               ⎛⎧
#                 mₕ      ⎟⎟│  │         ⎜               ⎜⎪               2⎛ mₕ
#            for ───── ≤ 1⎟⎟│  │         ⎜               ⎜⎪           asin ⎜────
#                    2    ⎟⎟│  │         ⎜               ⎜⎪                ⎝2⋅mₜ
#                4⋅mₜ     ⎟⎟│  │         ⎜               ⎜⎪
#                         ⎟⎟│  │         ⎜               ⎜⎪
# __    ⎞ ⎞               ⎟⎟│  │         ⎜               ⎜⎪       ⎛ ⎛      _____
# 2     ⎟ ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜ ⎜     ╱
#       ⎟ ⎟               ⎟⎟│  │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱
# ─  + 1⎟ ⎟               ⎟⎟│  │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 -
#       ⎟ ⎟               ⎟⎟│  │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱
#       ⎠ ⎟               ⎟⎟│  │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱
# ────────⎟               ⎟⎟│  │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜─────────────
# __      ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜        _____
# 2       ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜       ╱
#         ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜      ╱
# ─  - 1  ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜     ╱   1 -
#         ⎟               ⎟⎟│  │         ⎜               ⎜⎪       ⎜    ╱
#         ⎠               ⎟⎟│  │         ⎜               ⎜⎪       ⎝  ╲╱
# ─────────    otherwise  ⎟⎟│  │         ⎜               ⎜⎪─────────────────────
#                         ⎠⎠│  │         ⎝               ⎝⎩                4
# ──────────────────────────│ ⋅│────────────────────────────────────────────────
#                           │  │                                              4
#                           │  │                                        m_W⋅mₕ
#
#
#        ⎞⎞                   ⎛              ⎛⎧
#        ⎟⎟                   ⎜              ⎜⎪              2⎛  mₕ ⎞
# ─── ≤ 1⎟⎟                   ⎜              ⎜⎪          asin ⎜─────⎟
#   2    ⎟⎟                   ⎜              ⎜⎪               ⎝2⋅m_W⎠
# }}     ⎟⎟                   ⎜              ⎜⎪
#        ⎟⎟                   ⎜              ⎜⎪
#        ⎟⎟                   ⎜              ⎜⎪       ⎛      ______________    ⎞
#        ⎟⎟                   ⎜              ⎜⎪       ⎜     ╱        2         ⎟
#        ⎟⎟                   ⎜⎛         2 ⎞ ⎜⎪       ⎜    ╱    4⋅m_W          ⎟
#        ⎟⎟                 3 ⎜⎜     3⋅mₕ  ⎟ ⎜⎪       ⎜   ╱   - ────── + 1  + 1⎟
#        ⎟⎟   16⋅g_{hWW}⋅m_W ⋅⎜⎜-3 + ──────⎟⋅⎜⎨       ⎜  ╱         2           ⎟
#        ⎟⎟                   ⎜⎜          2⎟ ⎜⎪ 2    2⎜╲╱        mₕ            ⎟
#        ⎟⎟                   ⎜⎝     2⋅m_W ⎠ ⎜⎪π ⋅log ⎜────────────────────────⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎜          ______________⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎜         ╱        2     ⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎜        ╱    4⋅m_W      ⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎜1 -    ╱   - ────── + 1 ⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎜      ╱         2       ⎟
#        ⎟⎟                   ⎜              ⎜⎪       ⎝    ╲╱        mₕ        ⎠
#        ⎟⎟                   ⎜              ⎜⎪─────────────────────────────────
#        ⎠⎠                   ⎝              ⎝⎩                4
# ───────── - ──────────────────────────────────────────────────────────────────
#                                                                4
#                                                              mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#                       2     ⎞         ⎞           ⎛                      ⎛⎧
# ⎞                   mₕ      ⎟         ⎟           ⎜                      ⎜⎪
# ⎟              for ───── ≤ 1⎟         ⎟           ⎜                      ⎜⎪
# ⎠                      2    ⎟         ⎟           ⎜                      ⎜⎪
#                    4⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#                             ⎟         ⎟           ⎜                      ⎜⎪
# ______    ⎞ ⎞               ⎟         ⎟           ⎜                      ⎜⎪
#     2     ⎟ ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# 4⋅mₜ      ⎟ ⎟               ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪
# ─────  + 1⎟ ⎟               ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
#    2      ⎟ ⎟               ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#  mₕ       ⎠ ⎟               ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2
# ────────────⎟               ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅
# ______      ⎟               ⎟         ⎟           ⎜                      ⎜⎪
#     2       ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# 4⋅mₜ        ⎟               ⎟         ⎟           ⎜                      ⎜⎪
# ─────  - 1  ⎟               ⎟         ⎟           ⎜                      ⎜⎪
#    2        ⎟               ⎟         ⎟           ⎜                      ⎜⎪
#  mₕ         ⎠               ⎟         ⎟           ⎜                      ⎜⎪
# ─────────────    otherwise  ⎟         ⎟           ⎜                      ⎜⎪───
#                             ⎠         ⎠           ⎝                      ⎝⎩
# ─────────────────────────────────────── - ────────────────────────────────────
#
#
#
#
#          2      ⎞                  ⎞          ⎛                      ⎛⎧
#        mₕ       ⎟                  ⎟          ⎜                      ⎜⎪
#   for ────── ≤ 1⎟                  ⎟          ⎜                      ⎜⎪
#            2    ⎟                  ⎟          ⎜                      ⎜⎪
#       4⋅m_W     ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟       2       4  ⎟          ⎜   2      ⎛   2     ⎞ ⎜⎪
#                 ⎟   3⋅mₕ      mₕ   ⎟        4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪
#                 ⎟ + ────── + ──────⎟   80⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨
#                 ⎟        2        4⎟          ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2
#                 ⎟   4⋅m_W    8⋅m_W ⎟          ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#                 ⎟                  ⎟          ⎜                      ⎜⎪
#     otherwise   ⎟                  ⎟          ⎜                      ⎜⎪───────
#                 ⎠                  ⎠          ⎝                      ⎝⎩
# ──────────────────────────────────── + ───────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#                                                  2
#                                         2     ⎞⎞│
#             2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#         asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#              ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                      4⋅mₜ     ⎟⎟│
#                                               ⎟⎟│
#     ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
#     ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
#     ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#     ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
#     ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
#    2⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# log ⎜─────────────────────────⎟               ⎟⎟│
#     ⎜        ___________      ⎟               ⎟⎟│
#     ⎜       ╱         2       ⎟               ⎟⎟│
#     ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
#     ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
#     ⎜    ╱           2        ⎟               ⎟⎟│
#     ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ───────────────────────────────    otherwise  ⎟⎟│
#              4                                ⎠⎠│
# ────────────────────────────────────────────────│
#         4                                       │
#   m_W⋅mₕ                                        │
#
#                                              2
#                                     2     ⎞⎞│
#         2⎛ mₕ ⎞                   mₕ      ⎟⎟│
#     asin ⎜────⎟              for ───── ≤ 1⎟⎟│
#          ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                                  4⋅mₜ     ⎟⎟│
#                                           ⎟⎟│
# ⎛ ⎛      ___________    ⎞ ⎞               ⎟⎟│
# ⎜ ⎜     ╱         2     ⎟ ⎟               ⎟⎟│
# ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
# ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟               ⎟⎟│
# ⎜ ⎜  ╱           2      ⎟ ⎟               ⎟⎟│
# ⎜ ⎝╲╱          mₕ       ⎠ ⎟               ⎟⎟│
# ⎜─────────────────────────⎟               ⎟⎟│
# ⎜        ___________      ⎟               ⎟⎟│
# ⎜       ╱         2       ⎟               ⎟⎟│
# ⎜      ╱      4⋅mₜ        ⎟               ⎟⎟│
# ⎜     ╱   1 - ─────  - 1  ⎟               ⎟⎟│
# ⎜    ╱           2        ⎟               ⎟⎟│
# ⎝  ╲╱          mₕ         ⎠               ⎟⎟│
# ───────────────────────────    otherwise  ⎟⎟│
#          4                                ⎠⎠│
# ────────────────────────────────────────────│
#     4                                       │
# 3⋅mₕ                                        │
# ──────────────────────────────────────────────
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:41: RuntimeWarning: invalid value encountered in sqrt
#   return -(1/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mtop**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mtop**2))**-1))))*(-sp.I*np.pi))**2
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:165: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mWp**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mWp**2))**-1))))*(-sp.I*np.pi))**2;
# /home/moises/SpaceMath/SpaceMath/SpaceMath/HiggsDataPy/RXX.py:209: RuntimeWarning: invalid value encountered in sqrt
#   return -(1.0/4)*(np.log((1+np.sqrt(1-(((mS**2)/(4*mCH**2))**-1)))/(1-np.sqrt(1-(((mS**2)/(4*mCH**2))**-1))))*(- sp.I*np.pi))**2
# 0.02840367830613514

# %%
Rgg(ghtt,ghbb)
# Out:
#
#     │                ⎛               ⎛⎧
#     │                ⎜               ⎜⎪               2⎛ mₕ ⎞
#     │                ⎜               ⎜⎪           asin ⎜────⎟              for
#     │                ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#     │                ⎜               ⎜⎪
#     │                ⎜               ⎜⎪
#     │                ⎜               ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞
#     │                ⎜               ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟
#     │                ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟
#     │              3 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟
#     │16⋅g_{hbb}⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟ ⎟
#     │                ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟
#     │                ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟
#     │                ⎜               ⎜⎪       ⎜        ___________      ⎟
#     │                ⎜               ⎜⎪       ⎜       ╱         2       ⎟
#     │                ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟
#     │                ⎜               ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟
#     │                ⎜               ⎜⎪       ⎜    ╱           2        ⎟
#     │                ⎜               ⎜⎪       ⎝  ╲╱          mₕ         ⎠
#     │                ⎜               ⎜⎪──────────────────────────────────    o
#     │                ⎝               ⎝⎩                4
# 1.0⋅│─────────────────────────────────────────────────────────────────────────
#     │                                               4
#     │                                             mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#          │         ⎛               ⎛⎧
#          │         ⎜               ⎜⎪               2⎛ mₕ ⎞
#          │         ⎜               ⎜⎪           asin ⎜────⎟              for ─
#          │         ⎜               ⎜⎪                ⎝2⋅mₜ⎠
#          │         ⎜               ⎜⎪                                        4
#          │         ⎜               ⎜⎪
#          │         ⎜               ⎜⎪       ⎛ ⎛      ___________    ⎞ ⎞
#          │         ⎜               ⎜⎪       ⎜ ⎜     ╱         2     ⎟ ⎟
#          │         ⎜  ⎛       2  ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅mₜ      ⎟ ⎟
#          │       4 ⎜  ⎜     mₕ   ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ─────  + 1⎟ ⎟
#          │8⋅g⋅m_b ⋅⎜2⋅⎜1 - ──────⎟⋅⎜⎨       ⎜ ⎜  ╱           2      ⎟ ⎟
#          │         ⎜  ⎜         2⎟ ⎜⎪ 2    2⎜ ⎝╲╱          mₕ       ⎠ ⎟
#          │         ⎜  ⎝    4⋅m_b ⎠ ⎜⎪π ⋅log ⎜─────────────────────────⎟
#          │         ⎜               ⎜⎪       ⎜        ___________      ⎟
#          │         ⎜               ⎜⎪       ⎜       ╱         2       ⎟
#          │         ⎜               ⎜⎪       ⎜      ╱      4⋅mₜ        ⎟
#          │         ⎜               ⎜⎪       ⎜     ╱   1 - ─────  - 1  ⎟
#          │         ⎜               ⎜⎪       ⎜    ╱           2        ⎟
#          │         ⎜               ⎜⎪       ⎝  ╲╱          mₕ         ⎠
#          │         ⎜               ⎜⎪──────────────────────────────────    oth
#          │         ⎝               ⎝⎩                4
#          │────────────────────────────────────────────────────────────────────
#          │                                              4
#          │                                        m_W⋅mₕ
#
#
#     2     ⎞         ⎞                  ⎛                      ⎛⎧
#   mₕ      ⎟         ⎟                  ⎜                      ⎜⎪
#  ───── ≤ 1⎟         ⎟                  ⎜                      ⎜⎪           asi
#      2    ⎟         ⎟                  ⎜                      ⎜⎪
#  4⋅mₜ     ⎟         ⎟                  ⎜                      ⎜⎪
#           ⎟         ⎟                  ⎜                      ⎜⎪
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎛ ⎛
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜ ⎜
#           ⎟      2  ⎟                  ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜
#           ⎟    mₕ   ⎟                3 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱
#           ⎟ - ──────⎟   16⋅g_{htt}⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱
#           ⎟        2⎟                  ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱
#           ⎟   2⋅m_b ⎟                  ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜──────
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜     ╱
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎜    ╱
#           ⎟         ⎟                  ⎜                      ⎜⎪       ⎝  ╲╱
# therwise  ⎟         ⎟                  ⎜                      ⎜⎪──────────────
#           ⎠         ⎠                  ⎝                      ⎝⎩
# ───────────────────── - ──────────────────────────────────────────────────────
#                                                                       4
#                                                                     mₕ
# ──────────────────────────────────────────────────────────────────────────────
#
#   2     ⎞         ⎞           ⎛                      ⎛⎧
# mₕ      ⎟         ⎟           ⎜                      ⎜⎪               2⎛ mₕ ⎞
# ──── ≤ 1⎟         ⎟           ⎜                      ⎜⎪           asin ⎜────⎟
#    2    ⎟         ⎟           ⎜                      ⎜⎪                ⎝2⋅mₜ⎠
# ⋅mₜ     ⎟         ⎟           ⎜                      ⎜⎪
#         ⎟         ⎟           ⎜                      ⎜⎪
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎛ ⎛      _______
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜ ⎜     ╱
#         ⎟      2  ⎟           ⎜   2      ⎛   2     ⎞ ⎜⎪       ⎜ ⎜    ╱      4⋅
#         ⎟    mₕ   ⎟         4 ⎜ mₕ       ⎜ mₕ      ⎟ ⎜⎪       ⎜-⎜   ╱   1 - ──
#         ⎟ - ──────⎟   8⋅g⋅mₜ ⋅⎜───── + 2⋅⎜───── - 1⎟⋅⎜⎨       ⎜ ⎜  ╱
#         ⎟        2⎟           ⎜    2     ⎜    2    ⎟ ⎜⎪ 2    2⎜ ⎝╲╱          m
#         ⎟   2⋅m_b ⎟           ⎜2⋅mₜ      ⎝4⋅mₜ     ⎠ ⎜⎪π ⋅log ⎜───────────────
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜        _______
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜       ╱
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜      ╱      4⋅
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜     ╱   1 - ──
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎜    ╱
#         ⎟         ⎟           ⎜                      ⎜⎪       ⎝  ╲╱          m
# erwise  ⎟         ⎟           ⎜                      ⎜⎪───────────────────────
#         ⎠         ⎠           ⎝                      ⎝⎩                4
# ─────────────────── - ────────────────────────────────────────────────────────
#                                                                   4
#                                                             m_W⋅mₕ
#
#                                       4
#                              2     ⎞⎞│
#  2⎛ mₕ ⎞                   mₕ      ⎟⎟│
# n ⎜────⎟              for ───── ≤ 1⎟⎟│
#   ⎝2⋅mₜ⎠                      2    ⎟⎟│
#                           4⋅mₜ     ⎟⎟│
#                                    ⎟⎟│
#   ___________    ⎞ ⎞               ⎟⎟│
#  ╱         2     ⎟ ⎟               ⎟⎟│
# ╱      4⋅mₜ      ⎟ ⎟               ⎟⎟│
#    1 - ─────  + 1⎟ ⎟               ⎟⎟│
#           2      ⎟ ⎟               ⎟⎟│
#         mₕ       ⎠ ⎟               ⎟⎟│
# ───────────────────⎟               ⎟⎟│
#   ___________      ⎟               ⎟⎟│
#  ╱         2       ⎟               ⎟⎟│
# ╱      4⋅mₜ        ⎟               ⎟⎟│
#    1 - ─────  - 1  ⎟               ⎟⎟│
#           2        ⎟               ⎟⎟│
#         mₕ         ⎠               ⎟⎟│
# ────────────────────    otherwise  ⎟⎟│
#   4                                ⎠⎠│
# ─────────────────────────────────────│
#                                      │
#                                      │
# ───────────────────────────────────────
#                              4
#                     2     ⎞⎞│
#                   mₕ      ⎟⎟│
#              for ───── ≤ 1⎟⎟│
#                      2    ⎟⎟│
#                  4⋅mₜ     ⎟⎟│
#                           ⎟⎟│
# ____    ⎞ ⎞               ⎟⎟│
#   2     ⎟ ⎟               ⎟⎟│
# mₜ      ⎟ ⎟               ⎟⎟│
# ───  + 1⎟ ⎟               ⎟⎟│
#  2      ⎟ ⎟               ⎟⎟│
# ₕ       ⎠ ⎟               ⎟⎟│
# ──────────⎟               ⎟⎟│
# ____      ⎟               ⎟⎟│
#   2       ⎟               ⎟⎟│
# mₜ        ⎟               ⎟⎟│
# ───  - 1  ⎟               ⎟⎟│
#  2        ⎟               ⎟⎟│
# ₕ         ⎠               ⎟⎟│
# ───────────    otherwise  ⎟⎟│
#                           ⎠⎠│
# ────────────────────────────│
#                             │
#                             │
